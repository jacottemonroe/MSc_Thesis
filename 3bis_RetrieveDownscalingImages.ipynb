# %%
#!/usr/bin/env python

## MSC_Thesis 
## Jacotte Monroe 
## 19/03/24

## CHANGE DESCRIPTION BECAUSE THIS WAS COPY PASTED!!!
## Script that reads the spatial and temporal extents and retrieves the matching MODIS 250m images. 
## MODIS dataset is cloudmasked using a bitmask from MODIS 500m, then gap filled using temporal linear interpolation. 
## Each image is reprojected to EPSG 32733 (Namibia projection) and clipped to study area. 
## NDVI is calculated. 
## Script inputs: 
##       0_single_run_settings.csv
##       2_a1_step_extents.csv
## Script outputs: 
##       3_a1_modis_images (folder) > [daily_MODIS_NDVI_250m_date].tif (intermediate output) & 3_a2_modis_ndvi.tif (intermediate output)

## NOTE: Landsat images are large and may not get exported due to size limit. If that is the case, a manual download option is available. 
##       Run GEE code: https://code.earthengine.google.com/8b4653d8807cfa7ba185b45e18243e6d
##       The coordinates of the large region must be entered manually in the GEE script, then run, and export images in Task



###########
## Script set-up and loading necessary libraries 
###########

import ee
ee.Authenticate()

import geemap
import os
import pandas as pd
import math 

ee.Initialize()





# function to add timestamp band to image
# source: https://spatialthoughts.com/2021/11/08/temporal-interpolation-gee/
def addTimestamp(image): 
    # create new image where pixel value = time of original image
    timeImage = image.metadata('system:time_start').rename('timestamp')

    # mask new time image with original image to remove cloudmasked pixels
    timeImageMasked = timeImage.updateMask(image.mask().select(0))

    # return original image with time image as new band 
    return image.addBands(timeImageMasked)



# function that takes image and replaces masked pixels with linearly interpolated values from bef/aft images
def interpolateImage(image):
    image = ee.Image(image)

    # get list of before/after images from image property
    beforeImages = ee.List(image.get('before'))
    afterImages = ee.List(image.get('after'))

    # create image collection of before/after images
    # mosaic() combines images into one image accordint to their position in collection 
    #  image first has all pixels from last image in collection 
    #  gaps filled with second to last image from collection ...
    beforeMosaic = ee.ImageCollection.fromImages(beforeImages).mosaic()
    afterMosaic = ee.ImageCollection.fromImages(afterImages).mosaic()

    # rename time band of images 
    time_bef = beforeMosaic.select('timestamp').rename('time_bef')
    time_aft = afterMosaic.select('timestamp').rename('time_aft')
    time0 = image.metadata('system:time_start').rename('time0')

    # combine all three single band time images into one image with three time bands 
    timeImage = ee.Image.cat([time_bef, time_aft, time0])

    # compute image of interpolated surface reflectance values 
    timeRatio = timeImage.expression('(time0 - time_bef) / (time_aft - time_bef)', \
                    {'time0': timeImage.select('time0'), 
                     'time_bef': timeImage.select('time_bef'), 
                     'time_aft': timeImage.select('time_aft')})

    interpolated = beforeMosaic.add((afterMosaic.subtract(beforeMosaic).multiply(timeRatio)))

    # replace masked pixels in current image with pixels from interpolated mosaic
    result = image.unmask(interpolated)

    # return gap-filled image
    return result.copyProperties(image, ['system:time_start'])

# define landsat scaling factor
def applyScaleFactors(image): 
    opticalBands = image.select('SR_B.').multiply(0.0000275).add(-0.2)
    return image.addBands(opticalBands, None, True)

# function to reproject (32733 if want Namibia coordinates, but elephant fixes are in 4326)
def reprojectLandsat(image): 
    return image.reproject('EPSG:32733', None, 30)

def reprojectModis(image):
    return image.reproject('EPSG:32733', None, 250)

# function to clip image to study area
# have to include nested function because can't use map() with more than one argument 
# source: https://gis.stackexchange.com/questions/473500/mapping-function-with-multiple-arguments-in-google-earth-engine
def clipToAOI(bbox): 
    def withBbox(image):
        return image.clip(bbox).copyProperties(image, ['system:id'])
    return withBbox

# function to calculate NDVI 
def addNDVI(image): 
    ndvi = image.normalizedDifference(['nir', 'red']).rename('NDVI')
    return image.addBands(ndvi)



def retrieveImagesForDownscaling(): 
    ###########
    ## Read run settings 
    ###########
    run_settings_table = pd.read_csv('data/single_run_settings.csv', index_col = 0, header = None)

    # define settings
    ID = run_settings_table.iloc[0,0]
    week = str(run_settings_table.iloc[0,1])
    random_data_method = run_settings_table.iloc[0,2]

    print(ID)
    print(week)
    print(random_data_method)

    input_suffix = '_newPathWithCV'
    output_suffix = '_newPathWithCV'

    # check that the week setting doesn't preceed Landsat 8 data --> week >= 2259
    # Landsat starts 2013-03-18 meaning that week cannot be before 2013-04-18 (because 1 month buffer, see code below)
    # source: https://developers.google.com/earth-engine/datasets/catalog/LANDSAT_LC08_C02_T1_L2
    # if the week is before 2013-04-18, skip the iteration and go to next run 
    # source: https://www.tutorialspoint.com/python/python_loop_control.htm
    # CODE CURRENTLY GETTING ERROR THAT ITS NOT IN LOOP WHICH IS TRUE SO FOR NOW COMMENTED OUT AND HAVE TO MAKE SURE I GET THE RIGHT WEEKS
    #if week < 2259: 
     #   continue
    
    
    
    ###########
    ## Load step extents LUT
    ###########
    extents_lut = pd.read_csv('data/' + ID + '/' + week + '/' + '2_a1_step_extents_LUT_' + random_data_method + input_suffix + '.csv')

    
    
    ###########
    ## Create region (largest extent) geometry and define first and last dates
    ###########
    large_extent = extents_lut.iloc[-1]

    xmin = large_extent.loc['xmin']
    xmax = large_extent.loc['xmax']
    ymin = large_extent.loc['ymin']
    ymax = large_extent.loc['ymax']
    
    large_extent_coords = [[[xmin, ymin], [xmin, ymax], [xmax, ymax], [xmax, ymin]]]
    
    large_region = ee.Geometry.Polygon(large_extent_coords, proj = 'EPSG:32733', evenOdd = False)
    
    first_date = ee.Date(large_extent.loc['start_date_prev_week'], 'Africa/Maputo')
    week_start_date = ee.Date(large_extent.loc['start_date'], 'Africa/Maputo')
    last_date = ee.Date(large_extent.loc['end_date'], 'Africa/Maputo')
    
    # define landsat buffer (days) to make sure there are enough Landsat images being included
    l8_buffer = ee.Number(9)

    # create smaller geometries from large extent for Landsat download (loophole around file size limitation)
    xq1 = xmin + (xmax - xmin)*0.25
    xmid = xmin + (xmax - xmin)*0.5
    xq3 = xmin + (xmax - xmin)*0.75
    yq1 = ymin + (ymax - ymin)*0.25
    ymid = ymin + (ymax - ymin)*0.5
    yq3 = ymin + (ymax - ymin)*0.75

    large_extent_coords_TL_TL = [[[xmin, yq3], [xmin, ymax], [xq1, ymax], [xq1, yq3]]]
    large_extent_coords_TL_TR = [[[xq1, yq3], [xq1, ymax], [xmid, ymax], [xmid, yq3]]]
    large_extent_coords_TL_BR = [[[xq1, ymid], [xq1, yq3], [xmid, yq3], [xmid, ymid]]]
    large_extent_coords_TL_BL = [[[xmin, ymid], [xmin, yq3], [xq1, yq3], [xq1, ymid]]]
    
    large_extent_coords_TR_TL = [[[xmid, yq3], [xmid, ymax], [xq3, ymax], [xq3, yq3]]]
    large_extent_coords_TR_TR = [[[xq3, yq3], [xq3, ymax], [xmax, ymax], [xmax, yq3]]]
    large_extent_coords_TR_BR = [[[xq3, ymid], [xq3, yq3], [xmax, yq3], [xmax, ymid]]]
    large_extent_coords_TR_BL = [[[xmid, ymid], [xmid, yq3], [xq3, yq3], [xq3, ymid]]]
    
    large_extent_coords_BR_TL = [[[xmid, yq1], [xmid, ymid], [xq3, ymid], [xq3, yq1]]]
    large_extent_coords_BR_TR = [[[xq3, yq1], [xq3, ymid], [xmax, ymid], [xmax, yq1]]]
    large_extent_coords_BR_BR = [[[xq3, ymin], [xq3, yq1], [xmax, yq1], [xmax, ymin]]]
    large_extent_coords_BR_BL = [[[xmid, ymin], [xmid, yq1], [xq3, yq1], [xq3, ymin]]]

    large_extent_coords_BL_TL = [[[xmin, yq1], [xmin, ymid], [xq1, ymid], [xq1, yq1]]]
    large_extent_coords_BL_TR = [[[xq1, yq1], [xq1, ymid], [xmid, ymid], [xmid, yq1]]]
    large_extent_coords_BL_BR = [[[xq1, ymin], [xq1, yq1], [xmid, yq1], [xmid, ymin]]]
    large_extent_coords_BL_BL = [[[xmin, ymin], [xmin, yq1], [xq1, yq1], [xq1, ymin]]]

    large_region_TL_TL = ee.Geometry.Polygon(large_extent_coords_TL_TL, proj = 'EPSG:32733', evenOdd = False)
    large_region_TL_TR = ee.Geometry.Polygon(large_extent_coords_TL_TR, proj = 'EPSG:32733', evenOdd = False)
    large_region_TL_BR = ee.Geometry.Polygon(large_extent_coords_TL_BR, proj = 'EPSG:32733', evenOdd = False)
    large_region_TL_BL = ee.Geometry.Polygon(large_extent_coords_TL_BL, proj = 'EPSG:32733', evenOdd = False)
    
    large_region_TR_TL = ee.Geometry.Polygon(large_extent_coords_TR_TL, proj = 'EPSG:32733', evenOdd = False)
    large_region_TR_TR = ee.Geometry.Polygon(large_extent_coords_TR_TR, proj = 'EPSG:32733', evenOdd = False)
    large_region_TR_BR = ee.Geometry.Polygon(large_extent_coords_TR_BR, proj = 'EPSG:32733', evenOdd = False)
    large_region_TR_BL = ee.Geometry.Polygon(large_extent_coords_TR_BL, proj = 'EPSG:32733', evenOdd = False)
    
    large_region_BR_TL = ee.Geometry.Polygon(large_extent_coords_BR_TL, proj = 'EPSG:32733', evenOdd = False)
    large_region_BR_TR = ee.Geometry.Polygon(large_extent_coords_BR_TR, proj = 'EPSG:32733', evenOdd = False)
    large_region_BR_BR = ee.Geometry.Polygon(large_extent_coords_BR_BR, proj = 'EPSG:32733', evenOdd = False)
    large_region_BR_BL = ee.Geometry.Polygon(large_extent_coords_BR_BL, proj = 'EPSG:32733', evenOdd = False)
    
    large_region_BL_TL = ee.Geometry.Polygon(large_extent_coords_BL_TL, proj = 'EPSG:32733', evenOdd = False)
    large_region_BL_TR = ee.Geometry.Polygon(large_extent_coords_BL_TR, proj = 'EPSG:32733', evenOdd = False)
    large_region_BL_BR = ee.Geometry.Polygon(large_extent_coords_BL_BR, proj = 'EPSG:32733', evenOdd = False)
    large_region_BL_BL = ee.Geometry.Polygon(large_extent_coords_BL_BL, proj = 'EPSG:32733', evenOdd = False)


    
    ###########
    ## Load feature of Etosha National Park (Namibia) and transform into geometry
    ###########
    # load Etosha National Park study area
    enp = ee.Feature(ee.FeatureCollection('WCMC/WDPA/current/polygons') \
            .filter(ee.Filter.eq('ORIG_NAME', 'Etosha')) \
            .first())
    
    # create a buffer around the park to retrieve images that are slightly outside of ENP
    # source: https://developers.google.com/earth-engine/apidocs/ee-feature-buffer
    # note: buffered 10km around the park
    enp = enp.buffer(10000)
    
    # turn ENP study area into a geometry
    enp_geom = enp.geometry()
    


    ###########
    ## Set interpolation parameters 
    ###########
    # set time-window for interpolation (how far will interpolate)
    # note: this function only used for downscaling, data has already been handpicked for downscaling purposely to avoid cloudcover
    #       so there aren't many consecutive days without data --> time window can be kept relatively small 
    # source: https://spatialthoughts.com/2021/11/08/temporal-interpolation-gee/
    days = ee.Number(3) 
    
    # convert to milliseconds (for gap filling step)
    millis = days.multiply(1000*60*60*24)

    
    
    ###########
    ## Define path of output directory 
    ###########
    # define output folder paths for current MODIS images and images from week prior
    out_dir_m = 'data/' + ID + '/' + week + '/' + '3_b1_modis_images_downscaling_' + random_data_method + output_suffix + '/'
    out_dir_l = 'data/' + ID + '/' + week + '/' + '3_b2_landsat_images_downscaling_' + random_data_method + output_suffix + '/'
    
    print(out_dir_m)
    
    ###########
    ## Retrieve MODIS and Landsat datasets
    ###########
    # load daily MODIS 250m dataset 
    # source: https://developers.google.com/earth-engine/datasets/catalog/MODIS_061_MOD09GQ
    modis = ee.ImageCollection('MODIS/061/MOD09GQ') \
            .filterDate(first_date.advance(days.multiply(-1), 'day'), last_date.advance(days, 'day')) \
            .filterBounds(enp_geom) \
            .select(['sur_refl_b01', 'sur_refl_b02'], ['red', 'nir'])
    
    # load Landsat 8 level 2 
    # source: https://developers.google.com/earth-engine/datasets/catalog/LANDSAT_LC08_C02_T1_L2
    # source: https://developers.google.com/earth-engine/apidocs/ee-date-advance#colab-python
    # note: can't filter bounds with large_region until have reprojected image collections (meantime use enp_geom)
    # note: have to manually decide it take WRS_PATH 179 or 180 depending on where the large region is 
    # note: row 74 is necessary for LA14 datasets (LA26 doesn't need row 74)
    l8 = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2') \
            .filterDate(first_date.advance(l8_buffer.multiply(-1), 'day'), last_date.advance(l8_buffer, 'day')) \
            .filterBounds(enp_geom) \
            .filter(ee.Filter.inList('WRS_PATH', ee.List([179]))) \
            .filter(ee.Filter.inList('WRS_ROW', ee.List([73, 74]))) 
    
    
    
    ###########
    ## Image gap filling - Linear interpolation of missing pixels 
    ###########
    # interpolation of MODIS values necessary because the MODIS image is missing data on days of Landsat coverage (fill with bef/aft days)
    # add timestamp band to each image 
    modis_withTime = modis.map(addTimestamp)
    
    # following tutorial: https://spatialthoughts.com/2021/11/08/temporal-interpolation-gee/
    # define filter to only retrieve images within the specified time-window
    maxDiffFilter = ee.Filter.maxDifference(difference = millis, 
                                            leftField = 'system:time_start', 
                                            rightField = 'system:time_start')
    
    # define filters that compare given image timestamp against other image timestamps
    # NOTE: leftField compared against rightField --> so in first filter = leftField smaller than rightField
    greaterEqFilter = ee.Filter.greaterThanOrEquals(leftField = 'system:time_start', 
                                                    rightField = 'system:time_start')
    
    lessEqFilter = ee.Filter.lessThanOrEquals(leftField = 'system:time_start', 
                                              rightField = 'system:time_start')
    
    # combined filters --> find all images before/after image that are within time-window
    filter_before = ee.Filter.And(maxDiffFilter, greaterEqFilter)
    filter_after = ee.Filter.And(maxDiffFilter, lessEqFilter)
    
    # set join parameters
    # pairs each image to group of matching elements from the second collection 
    # saves the matching elements as new property with matchesKey name, ordered by date
    # order set to have the closest image as last element in list
    # source: https://spatialthoughts.com/2021/11/08/temporal-interpolation-gee/
    # source: https://developers.google.com/earth-engine/apidocs/ee-join-saveall
    join_before = ee.Join.saveAll(
        matchesKey = 'before', 
        ordering = 'system:time_start', 
        ascending = True)
    
    join_after = ee.Join.saveAll(
        matchesKey = 'after', 
        ordering = 'system:time_start', 
        ascending = False)
    
    # join the cloudfree MODIS 250m collection with itself to get all previous/post images within time-window
    # results in image collection where each image has a property that lists all images preceeding/following image within time-window
    # source: https://spatialthoughts.com/2021/11/08/temporal-interpolation-gee/
    modis_joined_temp = join_before.apply(
        primary = modis_withTime, 
        secondary = modis_withTime, 
        condition = filter_before)
    
    modis_joined = join_after.apply(
        primary = modis_joined_temp, 
        secondary = modis_joined_temp, 
        condition = filter_after)
    
    # interpolate all images from MODIS 250m image collection
    modis_interpolated = ee.ImageCollection(modis_joined.map(interpolateImage))


    
    ###########
    ## Preprocess images
    ###########
    # apply scaling factor on surface reflectance bands of Landsat to get reflectance values instead of digital numbers
    # source: https://www.usgs.gov/faqs/how-do-i-use-a-scale-factor-landsat-level-2-science-products
    l8_scaled = l8.map(applyScaleFactors).select(['SR_B.'])
    
    # reproject MODIS and Landsat datasets to Namibia projection 
    modis_interpolated = modis_interpolated.filterDate(first_date, last_date).select(['red', 'nir'])
    modis_reproj = modis_interpolated.map(reprojectModis)
    l8_reproj = l8_scaled.map(reprojectLandsat)
    
    # clip image
    modis_clipped = modis_reproj.map(clipToAOI(large_region))
    l8_clipped_TL_TL = l8_reproj.map(clipToAOI(large_region_TL_TL))
    l8_clipped_TL_TR = l8_reproj.map(clipToAOI(large_region_TL_TR))
    l8_clipped_TL_BR = l8_reproj.map(clipToAOI(large_region_TL_BR))
    l8_clipped_TL_BL = l8_reproj.map(clipToAOI(large_region_TL_BL))
    
    l8_clipped_TR_TL = l8_reproj.map(clipToAOI(large_region_TR_TL))
    l8_clipped_TR_TR = l8_reproj.map(clipToAOI(large_region_TR_TR))
    l8_clipped_TR_BR = l8_reproj.map(clipToAOI(large_region_TR_BR))
    l8_clipped_TR_BL = l8_reproj.map(clipToAOI(large_region_TR_BL))
    
    l8_clipped_BR_TL = l8_reproj.map(clipToAOI(large_region_BR_TL))
    l8_clipped_BR_TR = l8_reproj.map(clipToAOI(large_region_BR_TR))
    l8_clipped_BR_BR = l8_reproj.map(clipToAOI(large_region_BR_BR))
    l8_clipped_BR_BL = l8_reproj.map(clipToAOI(large_region_BR_BL))
    
    l8_clipped_BL_TL = l8_reproj.map(clipToAOI(large_region_BL_TL))
    l8_clipped_BL_TR = l8_reproj.map(clipToAOI(large_region_BL_TR))
    l8_clipped_BL_BR = l8_reproj.map(clipToAOI(large_region_BL_BR))
    l8_clipped_BL_BL = l8_reproj.map(clipToAOI(large_region_BL_BL))
    
    # add NDVI as a band to the MODIS dataset
    modis_ndvi = modis_clipped.map(addNDVI).select(['NDVI'])
    
    
    
    ###########
    ## Export MODIS and Landsat images 
    ###########
    # export MODIS image collection to local repository 
    # source: https://github.com/gee-community/geemap/blob/master/examples/notebooks/11_export_image.ipynb
    #geemap.ee_export_image_collection(modis_ndvi, out_dir = out_dir_m, region = large_region)
    
    # export Landsat 8 image collection to local repository 
    geemap.ee_export_image_collection(l8_clipped_TL_TL, out_dir = out_dir_l + 'TL_TL/', region = large_region_TL_TL)
    geemap.ee_export_image_collection(l8_clipped_TL_TR, out_dir = out_dir_l + 'TL_TR/', region = large_region_TL_TR)
    geemap.ee_export_image_collection(l8_clipped_TL_BR, out_dir = out_dir_l + 'TL_BR/', region = large_region_TL_BR)
    geemap.ee_export_image_collection(l8_clipped_TL_BL, out_dir = out_dir_l + 'TL_BL/', region = large_region_TL_BL)
    
    geemap.ee_export_image_collection(l8_clipped_TR_TL, out_dir = out_dir_l + 'TR_TL/', region = large_region_TR_TL)
    geemap.ee_export_image_collection(l8_clipped_TR_TR, out_dir = out_dir_l + 'TR_TR/', region = large_region_TR_TR)
    geemap.ee_export_image_collection(l8_clipped_TR_BR, out_dir = out_dir_l + 'TR_BR/', region = large_region_TR_BR)
    geemap.ee_export_image_collection(l8_clipped_TR_BL, out_dir = out_dir_l + 'TR_BL/', region = large_region_TR_BL)
    
    geemap.ee_export_image_collection(l8_clipped_BR_TL, out_dir = out_dir_l + 'BR_TL/', region = large_region_BR_TL)
    geemap.ee_export_image_collection(l8_clipped_BR_TR, out_dir = out_dir_l + 'BR_TR/', region = large_region_BR_TR)
    geemap.ee_export_image_collection(l8_clipped_BR_BR, out_dir = out_dir_l + 'BR_BR/', region = large_region_BR_BR)
    geemap.ee_export_image_collection(l8_clipped_BR_BL, out_dir = out_dir_l + 'BR_BL/', region = large_region_BR_BL)
    
    geemap.ee_export_image_collection(l8_clipped_BL_TL, out_dir = out_dir_l + 'BL_TL/', region = large_region_BL_TL)
    geemap.ee_export_image_collection(l8_clipped_BL_TR, out_dir = out_dir_l + 'BL_TR/', region = large_region_BL_TR)
    geemap.ee_export_image_collection(l8_clipped_BL_BR, out_dir = out_dir_l + 'BL_BR/', region = large_region_BL_BR)
    geemap.ee_export_image_collection(l8_clipped_BL_BL, out_dir = out_dir_l + 'BL_BL/', region = large_region_BL_BL)
    
    
    
    # # ###########
    # # ## Create and export mean MODIS NDVI image for large extent 
    # # ###########
    # # # This image will be used as basemap for visualization (no analysis done with it)
    # # # filter dataset to dates of week (remove week prior to movement)
    # # modis_week_ndvi = modis_ndvi.filterDate(week_start_date, last_date)
    
    # # # create mean NDVI raster
    # # # source: https://developers.google.com/earth-engine/guides/ic_reducing
    # # modis_ndvi_mean = modis_week_ndvi.mean()

    # # # reproject the raster in case it lost its projection (for some reason that happened?)
    # # modis_ndvi_mean = modis_ndvi_mean.reproject('EPSG:32733', None, 250)
    
    # # # export image
    # # geemap.ee_export_image(modis_ndvi_mean, filename = os.path.join(out_dir_m, "mean_ndvi.tif"), region = large_region, scale = 250)
    
    



# read the table with all run settings
all_runs = pd.read_csv('data/run_settings_downscaling.csv', index_col = 0)

#row = all_runs.iloc[[3]]
#row.to_csv('data/single_run_settings.csv', header = False)

# run function for MODIS image retrieval
#retrieveImagesForDownscaling()

# iteratte over each entry in the table 
for i in range(len(all_runs)):
    # save the run settings to be read in the function
    row = all_runs.iloc[[i]]
    row.to_csv('data/single_run_settings.csv', header = False)

    # run function for MODIS image retrieval
    retrieveImagesForDownscaling()
# Out:
# LA26
# 2260
# random_path_custom_distr
# data/LA26/2260/3_b1_modis_images_downscaling_random_path_custom_distr_newPathWithCV/
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/71a8e5e9fddf61ee790ad33c7635d4b7-0fc77a547dca8cd1594a14505b7ad474:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/9e529db1dc5ac1298da260ed51fc6231-4dae0030d1b1bc8a965894eeb1770aef:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/3d7216a3ae798aff829e6b1983d2d805-6c3fc9571ed7eaaec910a256f0bd4bf8:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/9397e682c05b37db06fffece577a452e-ee4adc9206d2d6666d0663ecee25428e:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/352957b8aa2f00e791969eb8336b5c11-faa2328a05b8d526b3423abf1ddb3b9b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/be0d9f07718e2102f1ef76500ab34592-1dd06d6c3ea965195dd4a935bb1389a6:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/24a86fa90039ac7e867dfff1974e8859-a8f857bf9327725c45a4b80cbfa265bc:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/ff1f4f409fb7c156f1b4cb5389a0b2db-534f5a27db26548429be1413f981fc3f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/62c8e9bdb4a2dfaf4d92600f4fbaceb2-dd7af27c8d5ebc3d7bb9a4e648756368:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e44d9e5a910f85d5d7df348e8ac5a3fc-dea72af6fed8e698a9dcbd7ac5bf6f4e:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/26ddec4220ea58ae887126d7af32986a-67fe720bc885b13da2642069a29b72ea:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/af12c9094f209cc490929a422b7d2556-3c3d35d7ed1fba24da722ab043f11538:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/bac26320c1c9ceccdc94a60ef7175951-75b1409a1ca7446be8b41c566a7f5586:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/caae5e3c89c6e9f7ef93fef5c209a26f-4bfc5bb952945efd624aadfaae9bdb19:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/817ceb0c8d740b051c4af4f1ecdb3c00-782810f6ef14c8a3c866aed797e4a788:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d08bf2c4fd8dca1a2325d92328e1cac9-774b4910e87c7a302e8d8237f3ca1d73:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/dfa215f6d0ede45789b2324db4d7594e-a4665a9abcdf999729003bfbb55816e7:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/a6d83090bdd9418114d7686567c11a99-723b841694e093f37660d33a127edd79:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/5959f96c5f2c62f3ec17a225220606e8-9b879648772d35fbc0f2c3577e3f1c43:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/221b9d9761e073ceb5ccbdd8f8ccfe1e-b1e9ffd88dd63420f2a926d6ef57c15c:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e8b0d008a3d67f47a458f4f401d816ae-2e26b037aadf2b55c51b3267bf6fdefb:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/1d60dcb9f6e801e7fafb7a6bbd493c26-5cc505ad86894f1afbfe2cafa0a836ee:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/2ae402a0e629efca6cae36959945a3a8-d8cf1331533c712bc0494322f40f2ab4:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/80f93cb544b0c4353304f470747b2ad7-a1c6e2e329e1d353fe24948aa6dee304:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BR/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/727159b93401c669a3a2bd7b2787287a-6766dca2ca0ee94799f181f42078fbb4:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BR/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BR/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/2000c0574eeee814206897384196dd9b-2decf4a63d16e13c43296f262bdcc761:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BR/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BR/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/30b1beb4bd72143bef884778aa620825-ed0c4fcf10aff6c61a6f76b2ca9d2a52:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BR/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BR/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/34ccf6dd9d6c765897883b9d4722bab0-39c7a3c1da9bcb21ffa01a21dad5e9cf:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BR/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BL/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/8f937cd8055900e4b5c124ce0a1b21af-8e967d7a6b936cee4f746dea84ab5025:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BL/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BL/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/9204dfae9ae9a24ec40f3d908632e6e0-bd5da160e223c528e46ce33cc0375dfb:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BL/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BL/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/3860c7623328e1b052cbc825fb058f06-f3647c151038e3bf603667add7f07d90:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BL/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BL/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b84ed37b17168d0b43e8e895d6c7744b-707b4806dbe7b5f46f223b4536ef89a8:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BL/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TL/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/f2ebd5dccbaca7873b8cfc2da88acd96-84ac8c61212d731c4366dda037b230ba:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TL/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TL/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/a54d794c685aab1d94bc6491a399fb0f-3863a7a91cbeba7a1f660c71d2fb28cf:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TL/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TL/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/2f0e757656967ef8f11ea75b9dfc1fcb-92b7ff679284482fa4b5911bd8a5991d:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TL/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TL/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/fe82fface1921363b275f59b474b40f5-7941645caf8340a08bb8126518b8fe8c:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TL/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b6373e76eaa5aaecc50f768220d18715-16fbc179078a063698c324fb87f90820:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e0aabc9fe43b280d410a78b60cc5da7d-0a1b5b6d752afc0d3ff3f6e293bebc95:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/a2fbbef0d8f0ef4660ae43d6b0a14692-fae5b582e0c5c9ba95ab5968d3bec258:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/c034d3c27881828981cf0a3b2687f4de-e4f48df7d74e9e338618513c24b8218f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/3ce7ad7268cec864e5b83d333066cde5-07d475430f0e6fea8713325af83e666b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/6b516e3451babb614853e837745cff18-5067331b5f25093944e32e8c89c43cbf:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/c4ebbf026d52055494d975f85d3d4ff2-6071944d60e134d6e8bac58d53a82f2a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/dc37d1d6e1e51ceb8a48ac900cab80b9-a30fa8ae0db567f84ee8f4bc38818125:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/498c786b3250c8c040b8cf12a61e4500-b38d93a82a9f578661b1618c61e03cbf:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/88ec6e2a0fc247ab4d221d9c97fd3515-29209e8883d9e2a2c431c830dcc13795:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b693aed7168008ae9d398058cbb145ae-e967af993cd42f2d4d725d5957eca8c5:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d6486d2c185deb54b5c436301bbf044b-3b41190f71a534d0b776b6ea921d980f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d23abc9ac16da3d9e9d85e2b34f12d63-5ace32bb5434a87b1ace07588536c7e2:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/6f9e62f750cb3cb8389b139da8af8e0f-32dec92b106eaa4d10f10ba26dc4850a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/88fa834f8c1342a4bc24ede709064240-6ea75756bb05925e78fd8ef1b9f4742e:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/a7ea71ce06ebd72369d1c6d396eab962-c38471f8f459eb206e70ada1450bc11d:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/bdea89b8542c06ced6e7a29d6d680be7-266372f54187c1aa1c2492cd135ddef6:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/a54a031db8cd90ab337a25b6e1f41396-2403edea3c16708450dd269e9033ab89:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d518fee202a56aeea9c27dded920ae9c-45b7253f0835a47885113fc69eb1fa5b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/01a69af208d26e24a9aa845aacf4c5fa-1aba297c9a093ea5418948900af80190:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/3c4e9ea328f7704c97fcf1ceea9cc66e-8784531cc699f669b7c1aad82be3aa24:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/af55f62025acbae679132ac458ba3065-a4439ff667769bb7b05267d92afe726b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/43939e8916e4ef8e57edc1ec59cc0241-3e15950e4c4a23bbe878398f734adcb2:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/55dcfbbb9b11bc0fafb08561278c86f5-bfdaef8ecf9b22aa42a77c4547b67a53:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/499c22fc5e266bcc627b1a4117d1b550-a77e05e3a92b0df66e375bc540d9da82:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/c659fc67b17b043de0d0eeba33a6857d-b9692e01a5e8996fcba052536371b0b0:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b624c0195042eecea635341fb5c0877a-127a8bdc25e2989edabb9af8576ae501:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/f7da3c5c371305885e890f22fa2948fe-e9b59b9c56153830a7d388e27abd2539:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179074_20130504.tif
#
#
# LA26
# 2267
# random_path_custom_distr
# data/LA26/2267/3_b1_modis_images_downscaling_random_path_custom_distr_newPathWithCV/
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179073_20130605.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/15368bb4668dc0b2ac7a7e19e13125d7-f414f2ba9b3499885b4809d1978d8c02:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179073_20130605.tif
#
#
# Exporting 2/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179073_20130621.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/1ec753ee935891f1157101b8432c8a15-efef850ae3a395d188be686e26ae9378:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179073_20130621.tif
#
#
# Exporting 3/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179074_20130605.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b6b8d23fd904e151eb8de76a9d8766ae-04eabdd59cbeb0ac397c296834d8da70:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179074_20130605.tif
#
#
# Exporting 4/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179074_20130621.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/f7d59dd183d9df43d9b60f333a6de802-152d3b3679686631dd81d2e8709dc28c:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TL/LC08_179074_20130621.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179073_20130605.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e389a2694859b498e4086f7bb1a7b384-45f798689cd6d9e9c45ed2feaf748349:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179073_20130605.tif
#
#
# Exporting 2/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179073_20130621.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/4ad253c69e08bb41307d2b648e5ad84c-82c43102800d9df0d32f1bca5fd374a5:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179073_20130621.tif
#
#
# Exporting 3/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179074_20130605.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/08ca8363a63c77282563b2709a7c97fa-1e8cecdaf68d8145eedfcf0e9c603ebd:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179074_20130605.tif
#
#
# Exporting 4/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179074_20130621.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/03b7be3c6ee6151eccdcfde09fb84561-1e1a0a972bd4c9429602da52fcd345ab:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_TR/LC08_179074_20130621.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179073_20130605.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/eb972b9dba7e13fce905934fccfb5202-12cce4d81ec9953985772bb770e607bf:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179073_20130605.tif
#
#
# Exporting 2/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179073_20130621.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/1c4619fb370803b5468a044092383df5-8ec092149fb509cb78d841c6f219fa56:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179073_20130621.tif
#
#
# Exporting 3/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179074_20130605.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/89dbd7a2de171bb53aee158ef472ad6b-8648aba9ce222c93734666dd74b9a039:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179074_20130605.tif
#
#
# Exporting 4/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179074_20130621.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/7bb7b5a7585878f0a3a548e4bcc29ae9-5e4f8e1b9c20cdf52f684d5883b0e219:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BR/LC08_179074_20130621.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179073_20130605.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/19c366f5f34750068867ac4c2145a82b-dfb0a5d502f52f8c6701462c2fc814b8:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179073_20130605.tif
#
#
# Exporting 2/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179073_20130621.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/c1883fe17dcc31bb4f7305dd9fbacb96-ef2003cab8264e1b232b76f76de43cd2:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179073_20130621.tif
#
#
# Exporting 3/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179074_20130605.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e5871dbdcd4238d5501674e890fd85ad-4eaa1b69f991d8a676cc92d14e3f1df7:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179074_20130605.tif
#
#
# Exporting 4/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179074_20130621.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/1684e33b1c5d4d07d7882fa072c455f7-bd6359f28d3a415850d9652fb84cf084:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TL_BL/LC08_179074_20130621.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179073_20130605.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/65f3f3a87aa4dda8aae7c7e106f4bd5a-0e253fcb6407d9c6b1ca1073bfa15be1:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179073_20130605.tif
#
#
# Exporting 2/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179073_20130621.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/184be73fd67e474bc04624f3098a8bac-c85e931c96fb88d7c565b1d0804414a7:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179073_20130621.tif
#
#
# Exporting 3/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179074_20130605.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/84102da129963ae1b66ccbf84ac69ae0-a6616ee6b9a54bb835b4b1bf2277dc5a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179074_20130605.tif
#
#
# Exporting 4/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179074_20130621.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/117886210faead1b420e2c383f6d548b-e3fc24bbcb0c53295b4b1715274a2f67:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TL/LC08_179074_20130621.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179073_20130605.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b4a470a6e7d882a990e079e8836ed11c-e1682a63642ecf8ad5ff6e3486757c18:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179073_20130605.tif
#
#
# Exporting 2/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179073_20130621.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d217ddf2fc0f2b4377fb0fae62a93696-c8fb42649218ba120c03b7c6e9917236:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179073_20130621.tif
#
#
# Exporting 3/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179074_20130605.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/71ca7a36ec7c32c361737070bbbf391a-a0dd2be42dd63620822f7ccac7cfe126:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179074_20130605.tif
#
#
# Exporting 4/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179074_20130621.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/57193bd10f987a1ee2476b2c168e2f89-4aad759359c28797aabf5b762b259fe4:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_TR/LC08_179074_20130621.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BR/LC08_179073_20130605.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/6f5276bd6ee71b5f2ec23e0560de7c77-3904880343fe79d24d005aed5bcb602a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BR/LC08_179073_20130605.tif
#
#
# Exporting 2/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BR/LC08_179073_20130621.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/cf60c6406b9927b12d153ea08c865e9a-10408c921a5150720d9c7d5d1c01af1e:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BR/LC08_179073_20130621.tif
#
#
# Exporting 3/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BR/LC08_179074_20130605.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/ad68a1a6d57a897e969fb1c0935bea18-9198b017d1009e25469c31dce801d31e:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BR/LC08_179074_20130605.tif
#
#
# Exporting 4/4: data/LA26/2267/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/TR_BR/LC08_179074_20130621.tif
# Generating URL ...
# ...
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TL/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TL/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/7a1742c9f77edf3a12f99e50744f289c-1dcad61227efe28d5ec8b73f2f4856f7:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TL/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TL/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/0409ea1bb06520e4ebd0616d621f3933-1bdbf9983129c3b416127d39a2dbc030:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TL/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/929c487a4a3faf745202d94902b98f40-60479ae6b0c8c6be5afa41dc27fabee7:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/2b22261468939ec9cb5ce469073562e1-deda1c7c553698c8cfa0f217383d5269:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/fbdc7f96914a1c32e4d6694055f5d243-adf66e8f6b39a2b261577f6b6be906e1:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/9fb7ca114d19d3bfe5f7b58cc72b43e1-1c1b672c67c127eaa1da20e96880628e:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_TR/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/31ae66d19cdd2c56fc21c3b8d78ec552-74be9e34220b51fdbe072821d142cf5b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/177f36c7180597b11bca0f9c3df3f85b-a2029c6c4a8d77544e53269606f4f37e:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/3f6606a6f0cd6b8de24c7c34fe40bb8e-4a1033073573be7f1e59e657da05d612:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/72a3eb4ecf8199294d1615dac9d2f952-2f379cac0b7ff23902d4c7fbc8d53a49:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BR/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/5f0c3c475fc7dd1cb4d44bdcb42de57c-41dac949ebcadd64b981f054ef8ddb03:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d9cd77fc9fe53f7c18d4534a9cbd769a-8865dacb6c0950674b25e67d1657cfaa:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/36793ca67a2fd64e2b68e3a17b6237a4-951c5fe99ceae15aedc2fc174e5714c4:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d2b994e46cbf167131e215cd5cbd3a1f-4b9977a624bca77b40b7d2b84e05f922:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BR_BL/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/99e4213163701c166d9ec546aba77958-549d382658965af7807f0a37c5160da9:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/69cab8f1820aa7a9234a9f5608bb4a95-28b7b1e53f55ec329b0de21684ed17e4:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/06568e1af4a759a376996debe5daff8c-8e0aaf5349966e6efce35b89b8799231:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/3fcb7360d7d961d465a7e74ec5580bd5-10c88e4ab0c6c5e6273266f442bb1cbe:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TL/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/ed3bf6b64950e0627743b572120b4cc8-66ad61d2277f5051ee45e9586c8cb7b5:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/8bf514c7be13773241dc6078423c2b25-350444cc5c2677ff2100b579f4737c8f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/67296881818c8e1ad1a7f9c71c57bc8e-d4f56a91352caa09c414270b4962e586:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/5c909a7c3f7d32f62d2c83ce4f586b4b-f0539aa0887ca28bbb99cac6ac5fde8f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_TR/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/785050cdf43292d6708187861764bb11-79c00b14873d5efbe36772991c2b5e8f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/1cda857f9606804fa56581a81834014a-518a1f3b852c970b24e77cac33b91fe1:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/819f49a22c68b4c959e28bc08e310ca3-04b1161455172308c0fefdc03f851eb3:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/5f11992ba590c9a69f58108bf100bac9-64adce1af7eb73df42be078dbdafa6c2:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BR/LC08_179074_20130504.tif
#
#
# Total number of images: 4
#
# Exporting 1/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179073_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d472726f7ee048f6961dab26f519ab01-b081556babb4aef677f1854793cfa3af:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179073_20130418.tif
#
#
# Exporting 2/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179073_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/6df7dcf27482078795a96abff44a24e5-55a84ff0a7b3f74da7bc11144e64534b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179073_20130504.tif
#
#
# Exporting 3/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179074_20130418.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/6f8a880a8974a37edc44e8b05ce8dfb9-699375a8b19c94c58ae5ba6de0b50c87:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179074_20130418.tif
#
#
# Exporting 4/4: data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179074_20130504.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/708d9b2297d7030b32b45fa903b3c924-0a2d1781730e99c5872cde886de207ef:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2260/3_b2_landsat_images_downscaling_random_path_custom_distr_newPathWithCV/BL_BL/LC08_179074_20130504.tif
