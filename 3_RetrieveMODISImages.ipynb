# %%
#!/usr/bin/env python

## MSC_Thesis 
## Jacotte Monroe 
## 19/03/24

## Script that reads the spatial and temporal extents and retrieves the matching MODIS 250m images. 
## MODIS dataset is cloudmasked using a bitmask from MODIS 500m, then gap filled using temporal linear interpolation. 
## Each image is reprojected to EPSG 32733 (Namibia projection) and clipped to study area. 
## NDVI is calculated. 
## Script inputs: 
##       0_single_run_settings.csv
##       2_a1_step_extents.csv
## Script outputs: 
##       3_a1_modis_images (folder) > [daily_MODIS_NDVI_250m_date].tif (intermediate output) & 3_a2_modis_ndvi.tif (intermediate output)

 

###########
## Script set-up and loading necessary libraries 
###########

import ee
ee.Authenticate()

import geemap
import os
import pandas as pd
import math 

ee.Initialize()



###########
## Functions needed to run the script 
###########

# function to extract and combined relevant QA band bits/flags 
# source: https://mygeoblog.com/2017/09/08/modis-cloud-masking/
def getQABits(image, start_bit, end_bit, band_name):
    pattern = 0
    
    # for each bit/flag of the QA band --> assign new value to its bits 
    # so each flag will have a different value and the pixel will be the sum of all flags 
    for i in range(start_bit, end_bit):
        pattern += math.pow(2,i)
    # return single band image of extracted QA bits
    # source: https://developers.google.com/earth-engine/apidocs/ee-image-bitwiseand
    return image.select([0], [band_name]) \
                .bitwiseAnd(pattern) \
                .rightShift(start_bit)



# function to mask out cloudy pixels 
# source: https://gis.stackexchange.com/questions/308456/get-a-mask-for-modis-250m-mod09gq-using-modis-500m-mod09ga-in-google-earth
# source: https://mygeoblog.com/2017/09/08/modis-cloud-masking/
def maskClouds(image):
    # selects the MODIS 500m QA band 
    QA = image.select('state_1km')

    # creates a cloud&shadow flag from specified bits --> in this case: 'Cloud state' and 'Cloud shadow'
    pixelQuality = getQABits(QA, 0, 2, 'cloud_and_shadow_quality_flag')

    # returns image masking out cloudy pixels 
    return image.updateMask(pixelQuality.eq(0))



# function to add timestamp band to image
# source: https://spatialthoughts.com/2021/11/08/temporal-interpolation-gee/
def addTimestamp(image): 
    # create new image where pixel value = time of original image
    timeImage = image.metadata('system:time_start').rename('timestamp')

    # mask new time image with original image to remove cloudmasked pixels
    timeImageMasked = timeImage.updateMask(image.mask().select(0))

    # return original image with time image as new band 
    return image.addBands(timeImageMasked)



# function that takes image and replaces masked pixels with linearly interpolated values from bef/aft images
def interpolateImage(image):
    image = ee.Image(image)

    # get list of before/after images from image property
    beforeImages = ee.List(image.get('before'))
    afterImages = ee.List(image.get('after'))

    # create image collection of before/after images
    # mosaic() combines images into one image accordint to their position in collection 
    #  image first has all pixels from last image in collection 
    #  gaps filled with second to last image from collection ...
    beforeMosaic = ee.ImageCollection.fromImages(beforeImages).mosaic()
    afterMosaic = ee.ImageCollection.fromImages(afterImages).mosaic()

    # rename time band of images 
    time_bef = beforeMosaic.select('timestamp').rename('time_bef')
    time_aft = afterMosaic.select('timestamp').rename('time_aft')
    time0 = image.metadata('system:time_start').rename('time0')

    # combine all three single band time images into one image with three time bands 
    timeImage = ee.Image.cat([time_bef, time_aft, time0])

    # compute image of interpolated surface reflectance values 
    timeRatio = timeImage.expression('(time0 - time_bef) / (time_aft - time_bef)', \
                    {'time0': timeImage.select('time0'), 
                     'time_bef': timeImage.select('time_bef'), 
                     'time_aft': timeImage.select('time_aft')})

    interpolated = beforeMosaic.add((afterMosaic.subtract(beforeMosaic).multiply(timeRatio)))

    # replace masked pixels in current image with pixels from interpolated mosaic
    result = image.unmask(interpolated)

    # return gap-filled image
    return result.copyProperties(image, ['system:time_start'])



# function to reproject (elephant fixes reprojected from 4326 to 32733 same needs to be done to images) 
def reprojectModis(image):
    return image.reproject('EPSG:32733', None, 250)



# function to clip image to study area
# have to include nested function because can't use map() with more than one argument 
# source: https://gis.stackexchange.com/questions/473500/mapping-function-with-multiple-arguments-in-google-earth-engine
def clipToAOI(bbox): 
    def withBbox(image):
        return image.clip(bbox).copyProperties(image, ['system:id'])
    return withBbox



# function to calculate NDVI 
def addNDVI(image): 
    ndvi = image.normalizedDifference(['nir', 'red']).rename('NDVI')
    return image.addBands(ndvi)



def retrieveMODISImages(): 
    # source: https://stackoverflow.com/questions/44116194/import-a-function-from-another-ipynb-file
    #from ipynb.fs.defs.pythonFunctions import getQABits, maskClouds, addTimestamp, interpolateImage, reprojectMODIS, clipToAOI, addNDVI
    
    ###########
    ## Read run settings 
    ###########
    run_settings_table = pd.read_csv('data/single_run_settings.csv', index_col = 0, header = None)

    ID = run_settings_table.iloc[0,0]
    week = str(run_settings_table.iloc[0,1])
    random_data_method = run_settings_table.iloc[0,2]
    input_suffix = run_settings_table.iloc[0,5]
    output_suffix = run_settings_table.iloc[0,6]

    # replace NA from suffix columns of run settings to empty strings
    #if input_suffix.isna(): 
     #   input_suffix = ''
    #if output_suffix.isna(): 
     #   output_suffix = ''
        

    ###########
    ## Load step extents LUT
    ###########
    extents_lut = pd.read_csv('data/' + ID + '/' + week + '/' + '2_a1_step_extents_LUT_' + random_data_method + input_suffix + '.csv')



    ###########
    ## Create region (largest extent) geometry and define first and last dates
    ###########
    large_extent = extents_lut.iloc[-1]

    large_extent_coords = [[[large_extent.loc['xmin'], large_extent.loc['ymin']],
                            [large_extent.loc['xmin'], large_extent.loc['ymax']],
                            [large_extent.loc['xmax'], large_extent.loc['ymax']],
                            [large_extent.loc['xmax'], large_extent.loc['ymin']]]]
    
    large_region = ee.Geometry.Polygon(large_extent_coords, proj = 'EPSG:32733', evenOdd = False)
    
    first_date = ee.Date(large_extent.loc['start_date_prev_week'], 'Africa/Maputo')
    week_start_date = ee.Date(large_extent.loc['start_date'], 'Africa/Maputo')
    last_date = ee.Date(large_extent.loc['end_date'], 'Africa/Maputo')


    
    ###########
    ## Load feature of Etosha National Park (Namibia) and transform into geometry
    ###########
    # load Etosha National Park study area
    enp = ee.FeatureCollection('WCMC/WDPA/current/polygons') \
            .filter(ee.Filter.eq('ORIG_NAME', 'Etosha'))
    
    # turn ENP study area into a geometry
    enp_geom = enp.geometry()


    
    ###########
    ## Set interpolation parameters 
    ###########
    # set time-window for interpolation (how far will interpolate)
    # source: https://spatialthoughts.com/2021/11/08/temporal-interpolation-gee/
    days = ee.Number(30) 
    
    # convert to milliseconds (for gap filling step)
    millis = days.multiply(1000*60*60*24)


    
    ###########
    ## Define path of output directory 
    ###########
    # define output folder paths for current MODIS images and images from week prior
    out_dir = 'data/' + ID + '/' + week + '/' + '3_a1_modis_images_' + random_data_method + output_suffix + '/'
    
    
    
    ###########
    ## Retrieve MODIS datasets and combine into one dataset
    ###########
    # load MODIS 250m dataset 
    # take larger time range to include images for gap filling of cloudmasked pixels 
    # source: https://developers.google.com/earth-engine/apidocs/ee-date-advance#colab-python
    modis_250 = ee.ImageCollection('MODIS/061/MOD09GQ') \
            .filterDate(first_date.advance(days.multiply(-1), 'day'), last_date.advance(days, 'day')) \
            .filterBounds(enp_geom)
    
    # import MODIS 500m dataset (contains information for cloudmasking)
    modis_500 = ee.ImageCollection('MODIS/006/MOD09GA') \
            .filterDate(first_date.advance(days.multiply(-1), 'day'), last_date.advance(days, 'day'))  \
            .filterBounds(enp_geom)
    
    # combine datasets
    # pixel with certain MODIS 500m value can be selected for MODIS 250m 
    # source: https://gis.stackexchange.com/questions/308456/get-a-mask-for-modis-250m-mod09gq-using-modis-500m-mod09ga-in-google-earth
    modis_combined = modis_500.combine(modis_250)
    
    # new name of MODIS 250m bands (to avoid having two of similar name)
    modisBands = ['sur_refl_b01_1', 'sur_refl_b02_1']
    renamedBands = ['red', 'nir']



    ###########
    ## Create cloud free MODIS 250m dataset
    ###########
    # source: https://mygeoblog.com/2017/09/08/modis-cloud-masking/ 
    # source: https://gis.stackexchange.com/questions/308456/get-a-mask-for-modis-250m-mod09gq-using-modis-500m-mod09ga-in-google-earth
    
    modis_cloudFree = modis_combined.map(maskClouds).select(modisBands, renamedBands)

    
    ###########
    ## Image gap filling - Linear interpolation of missing pixels 
    ###########
    # add timestamp band to each image 
    modis_cloudFree_withTime = modis_cloudFree.map(addTimestamp)
    
    # following tutorial: https://spatialthoughts.com/2021/11/08/temporal-interpolation-gee/
    # define filter to only retrieve images within the specified time-window
    maxDiffFilter = ee.Filter.maxDifference(difference = millis, 
                                            leftField = 'system:time_start', 
                                            rightField = 'system:time_start')
    
    # define filters that compare given image timestamp against other image timestamps
    # NOTE: leftField compared against rightField --> so in first filter = leftField smaller than rightField
    greaterEqFilter = ee.Filter.greaterThanOrEquals(leftField = 'system:time_start', 
                                                    rightField = 'system:time_start')
    
    lessEqFilter = ee.Filter.lessThanOrEquals(leftField = 'system:time_start', 
                                              rightField = 'system:time_start')
    
    # combined filters --> find all images before/after image that are within time-window
    filter_before = ee.Filter.And(maxDiffFilter, greaterEqFilter)
    filter_after = ee.Filter.And(maxDiffFilter, lessEqFilter)
    
    # set join parameters
    # pairs each image to group of matching elements from the second collection 
    # saves the matching elements as new property with matchesKey name, ordered by date
    # order set to have the closest image as last element in list
    # source: https://spatialthoughts.com/2021/11/08/temporal-interpolation-gee/
    # source: https://developers.google.com/earth-engine/apidocs/ee-join-saveall
    join_before = ee.Join.saveAll(
        matchesKey = 'before', 
        ordering = 'system:time_start', 
        ascending = True)
    
    join_after = ee.Join.saveAll(
        matchesKey = 'after', 
        ordering = 'system:time_start', 
        ascending = False)
    
    # join the cloudfree MODIS 250m collection with itself to get all previous/post images within time-window
    # results in image collection where each image has a property that lists all images preceeding/following image within time-window
    # source: https://spatialthoughts.com/2021/11/08/temporal-interpolation-gee/
    modis_joined_temp = join_before.apply(
        primary = modis_cloudFree_withTime, 
        secondary = modis_cloudFree_withTime, 
        condition = filter_before)
    
    modis_joined = join_after.apply(
        primary = modis_joined_temp, 
        secondary = modis_joined_temp, 
        condition = filter_after)
    
    # interpolate all images from MODIS 250m image collection
    modis_interpolated = ee.ImageCollection(modis_joined.map(interpolateImage))
    
    
    
    ###########
    ## Look over each step extent entry in the LUT to export corresponding image 
    ###########
    # 1. get dates
    # 2. get coordinates 
    # 3. turn into geometry
    # 4. get MODIS image
    # 5. reproject 
    # 6. clip
    # 7. calculate NDVI
    # 8. export image
    
    for i in range(len(extents_lut)-1):
        # select entry
        extent = extents_lut.iloc[i]
        
        # retrieve extent dates 
        start_date = extent.loc['start_date']
        end_date = extent.loc['end_date']
        
        start_date_prev_week = extent.loc['start_date_prev_week']
        end_date_prev_week = extent.loc['end_date_prev_week']
        
        # retrieve extent coordinates 
        # source: https://sparkbyexamples.com/pandas/pandas-get-cell-value-from-dataframe/?utm_content=cmp-true
        # source: https://stackoverflow.com/questions/75203044/how-to-create-polygon-from-bbox-data-in-pythonv
        coords = [[[extent.loc['xmin'], extent.loc['ymin']],
                  [extent.loc['xmin'], extent.loc['ymax']],
                  [extent.loc['xmax'], extent.loc['ymax']],
                  [extent.loc['xmax'], extent.loc['ymin']]]]
    
        # create geometry from coordinates
        bbox = ee.Geometry.Polygon(coords, proj = 'EPSG:32733', evenOdd = False)
        
        # retrieve MODIS 250m image for geometry 
        modis = modis_interpolated \
            .filterDate(start_date, end_date) \
            .filterBounds(enp_geom) \
            .select(['nir', 'red']) 
        
        modis_prev_week = modis_interpolated \
            .filterDate(start_date_prev_week, end_date_prev_week) \
            .filterBounds(enp_geom) \
            .select(['nir', 'red']) 
        
        # reproject image
        modis_reproj = modis.map(reprojectModis)
        
        modis_prev_week_reproj = modis_prev_week.map(reprojectModis)
        
        # clip image
        modis_clipped = modis_reproj.map(clipToAOI(bbox))
        
        modis_prev_week_clipped = modis_prev_week_reproj.map(clipToAOI(bbox))
    
        # calculate NDVI 
        modis_ndvi = modis_clipped.map(addNDVI).select(['NDVI'])
    
        modis_ndvi_prev_week = modis_prev_week_clipped.map(addNDVI).select(['NDVI'])
        
        # export MODIS image to local repository 
        # source: https://github.com/gee-community/geemap/blob/master/examples/notebooks/11_export_image.ipynb
        geemap.ee_export_image_collection(modis_ndvi, out_dir = out_dir, region = large_region)
        
        geemap.ee_export_image_collection(modis_ndvi_prev_week, out_dir = out_dir, region = large_region)
    
    
    
    ###########
    ## Create and export mean NDVI image for large extent 
    ###########
    # This image will be used as basemap for visualization (no analysis done with it)
    # filter dataset to dates
    modis_week = modis_interpolated \
        .filterDate(week_start_date, last_date) \
        .filterBounds(enp_geom).select(['nir', 'red']) 
    
    # calculate NDVI 
    modis_week_ndvi = modis_week.map(addNDVI).select(['NDVI'])
    
    # create mean NDVI raster
    # source: https://developers.google.com/earth-engine/guides/ic_reducing
    modis_ndvi_mean = modis_week_ndvi.mean()
    
    # reproject image
    modis_ndvi_mean = modis_ndvi_mean.reproject('EPSG:32733', None, 250)
    
    # clip image
    modis_ndvi_mean = modis_ndvi_mean.clip(large_region)
    
    # export image
    geemap.ee_export_image(modis_ndvi_mean, filename = os.path.join(out_dir, "mean_ndvi.tif"), region = large_region, scale = 250)

    return print('(DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.')
    #print('Now extracting covariates...')


# read the table with all run settings
all_runs = pd.read_csv('data/run_settings_new_path_with_CV_until_486.csv', index_col = 0)

# iterate over each entry in the table 
for i in range(len(all_runs)):
    # save the run settings to be read in the function
    row = all_runs.iloc[[i]]
    row.to_csv('data/single_run_settings.csv', header = False)

    # run function for MODIS image retrieval
    retrieveMODISImages()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_30.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/ca3fd3360e3ddcb9341ee390da338ac3-78092169add279262f4f780ea173d18a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_30.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d5ac0a775dde6dcffbbbc62149a9ba9b-05fe09df31a3e621de9429387d7e5050:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_23.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_31.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/afe7800fe2d98c8d1936ea95fdf8186b-40513562964e6672662ec55e7854a583:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_31.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_24.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e5456ff476291e218f990f76debb4e51-e975b7f0abd2312d0bc70c0dc57fa238:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_24.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/caf75e7b29cd6c5d071e66bd2110a1f2-52a25c86ffd601c4938b514ae9f5a9df:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_01.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_25.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/3e0550bf7ea4322c9aa5c0733a07ad07-fb335b1a4dae7100edc3598bb13f7d79:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_25.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/05d3e5aa46a05a728a308738485255f3-d674c55c54eb9922845f6fa9c8530275:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_02.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_26.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e504450c364c916f10f123f9f71e9da2-ad7ba1f0b916e7ad2c37cbfa403c42d2:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_26.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/167758a04e6c5cb5fc31baf7a65b6145-20b4aaf70f081c97ac5ee46efc28c53d:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_03.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_27.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/1ca693c82cfb7efed6c0bbe2e32df21f-3c01a18ae7fd7d95f6e2bd76d57b8f6a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_27.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/ed0a1f509d803531443fd1ad66b87606-8c0e1d0aab3264107d537edd1acde382:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_04.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_28.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/a66670769073d136c2adb09e3a61b34e-c8f6d87fd196b6f957978c573d503d1c:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_28.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/04037712874334385b57caf8243b2ce4-701297fcf902e5eb8216be03887b4e9f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_05.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_29.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/c80ab15e7be54ad3ed7a48486b334c79-0d691135c1722573759332009d241c7d:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_29.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/2d1c7f24341b7623cad4ba32f0f0401f-792b5c2fcfdee1ba59d17471656a7775:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2065/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/cfff1ac3fcd9a33c1083d73ccfafbf36-76251997f3878678da3d5f2b76fc20f1:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_06.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_30.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d51a1b8be53706f477ad91d7c07d3e72-de17c0ff4675d69bdc73a42cb7a5c480:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_30.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e415114249014ce47b7e2d942a387201-b744fa54937b8b39e318ac7304b9b929:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_07.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_31.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e89b263a59b18a32d10974b46e6d6f7f-f2c4b456c890922be16764e484ac239a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_07_31.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/cfe0226d6db5d89c058b85476c8b0e45-d99e65a52f8c47f1abc37b432e8d5023:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_08.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/a10aed40c301916f8fb63cccfb0e16b0-4929d24611f51f85acd48a7f7dfe2c66:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_01.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e0eb24712db45d7a99d25344c0e86e64-68308a5a0e8730b55609789451a343ff:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_09.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/1190db28237163cd54eb1cad2d9e720f-5174f420ea18ce6ef1048f282c9993cf:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_02.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/23eaff0a9bf3a34cab6c7441f81a3463-7c66c04d911eb4c5e0a276a2d61bdf94:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_10.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b52831863762e44a0ddcb844b8c82c6c-93581d5cb12b52ba3193cabfc2ae7108:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_03.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/2a522b6b32b149cf333ac09bd67f702d-e063b7f51d3fecf6551fcc12eae19ca4:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_11.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/0215804f2cba99d8654def974915803e-4a6494ec6938c722ecbb8609446fc5b8:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_04.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/a3f502ea9ed26fc2075414bf0ca048be-a215c49cfd8f4a8610ba5774002739f5:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_12.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/72de145c5825f0513d68da637be98037-b269e6cf117244817ffc708470e1b84e:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_05.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/502731ab83906b59405d0753c3b35619-d69dc76f7cba696877993af2e45047c0:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2066/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/08f3735ddf09f62a197b6d473f18fa44-5ed223dc7c01663fdbb8ea72d7df61fd:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_13.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/ff6594762a03068df98201c439e21b8c-ec97e4f2c9e49cb7a097ef67d97b2002:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_06.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/6a424acec6bb89632c35798941e31b01-c3e0ea427b56bff70b6469ede97e2b39:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_14.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/f9f7b69a8f6d7682642200588e89a08f-b568676e3ebb5ec9a759314abb0f470f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_07.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/5528a085003c67bd05f38153b04f3448-373b04f672dd2c5db0bc0d6be7f29599:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_15.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/03c7b12debd7007a2029a138fb66ffc5-afd8af49946ef3fb0489e8b6afa8b77e:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_08.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_16.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/ca37051e3088943c4fa17f5e5f78bcc5-03ab0cde0fbbdfc43b27fa71f1b4d068:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_16.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/5b2c3c822f0d497073c049958f59dbb7-f25a6c519919993fb3e8d9218c31b377:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_09.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_17.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/08ecfe67c984cedea15bd9a67078485d-fea73ea72e083ec031e6678102ca7946:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_17.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/1293f66fa3a4964d89e98ee2f96e868a-e61a9fe7407361b401adb82255af516a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_10.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/456c7625f69773e4c69fd5c45eb16381-ac95c854bc7ee0373471ffdd60206133:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_18.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/34955d6b5981d6f168d7b4c1ed786a7f-a8060122462c1cf333ce132f79516cc7:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_11.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/132e3b284e3af77bf5625fb2e5fb0b95-31d7a0d6c3bd9fc6f43d6a560aded267:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_19.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/69150ebd3c5d21d998aaa451e23650be-db5d5dbb7b69b66b07c489b2c96f8822:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_12.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/8bbb33d5ca84b5773708e010e3e13b23-0ae3dde3e637387af0c4344162fd530f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2067/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/ed13dc5b02ee99266be08a4aa29ac7d5-5eadc89a2048e281c67af47da762ab50:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_20.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/22c130937f84b356b7448ce8a527e8aa-de3c7b6b091664952e56d6ce7b70e402:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_13.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b92133c8cf1437e681bea4132b1b7bdd-8b34431af0284c3527b5bbb2e3d19e56:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_21.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/8b1637a9b80684efbb11472a7b06b974-ed9f564bb810bdf31f8374479498db81:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_14.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/3ee59f0babf54e1c01fd3d41da1f7351-dfa667e77297be7da6875051226d4055:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_22.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/7de6fd295e00099a77fe541f7b0ef440-9b7922a2553e7e1ab73f5d793a8228b5:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_15.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/0b0e8af4d639bfc6e6d2c49a03f6f900-4a8330476a2f626865ab6698619facba:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_23.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_16.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b840abda2688f42f800a14b5821d297a-a9c20774d03e61cbf4583aea6f70ddf6:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_16.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_24.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/f3af3887ab420fd43cad60a7bab944f1-32e28e637177a5a0124bac78d8948b76:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_24.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_17.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d921096eae453ba968f9519bbe82a143-3cdd60b79d577932f141023a2a812a10:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_17.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_25.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/0132cb2a1655dd1bdf78170b96598d67-82d793639b29316766da031bbce71107:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_25.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/16dbb526b5f1d76a5d0c1fd890cae0d2-69db50564d4ad6f296177e01f2fa92bd:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_18.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_26.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/325ef769f79f5b77e1b101ddebb78021-dfd5d27d36196b4eda613ce52a1703a0:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_26.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e962e64510d2df021f5a7831095f936b-2849cf4ef4d45bf424bfb3a8e6268af5:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_19.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/4c7f1de4798cb9d6a6bd1d81946505d1-012b2e58fe3e33707961a20a41fe4970:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2068/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_27.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/608988e7bbb53e6c24e8c0c2ef2de60e-d4434b5d3fa6478167f163c4b67382a0:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_27.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/9e00ddd388acdfe55890777c1e41f8c8-6286e7c6fd697d2c4cb77634dceee99e:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_20.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_28.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/4d7ed92d6975cb6ca8d9d1ba0e29553d-af20da435421cb6e4344636f6db6eb0f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_28.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/cc10abc731e79e8b6b9ad737cfd8b128-367a049b4fddf52838761363d2b834c5:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_21.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_29.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/c709b19e59c9605b1072b674897cdfd2-96a83faa2bfced7a4cb1c3cb3a6fd63a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_29.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/381c7431221cdcd5153915836b4019bc-c60e4f02353c37b4d1b1deed3d7adf88:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_22.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_30.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/4ab9901de4f2206880fab73c94b40d9a-f0489d21f39809a05410882b3f39cc40:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_30.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/c04e858152c7c361116303eba4a00afb-873c6d5dcc6060289dd48017dfe2f90b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_23.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_31.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/5dad405ac5c0cdf4757d9e1de9533b49-1a772cab4db2d9c4257fe45c489e74ad:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_31.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_24.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/34ec881523fdb843c41c8721abfbbd4c-42cf81da5f6ed8dec9f6b57a8b1c1479:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_24.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/6b81f448d42d6982334edd0fcd914334-1bddccb3c85214ab898aa2d3c4d8794f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_01.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_25.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/11a0c8c332eb734e5209bdd01951165d-d48be2f5baf85deb08e3839e6d3996cf:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_25.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/f521fb0c6623016ded5d101ffd8c5622-5bdfca675949b4d133a7242f5ee98872:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_02.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_26.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/711a6fc418e55fae509ec5d5631e8bd4-9aab8bf14651422431b7a77ef43a0b9a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_26.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/70217e33895524dd3e8a8c97b1dcaba3-869359ac1cc456095a3789d88b22e523:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/3a5b43fa4926476435feb38b5915e846-b376d9bf78a5ceed55ed0258a61489b2:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_03.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_27.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/9c6948761ab7bee40a0c1ea2274784b1-a26de4eaeeff428f91afcd833d57d880:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_27.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/3c5c2919542b33392a0bd36788f1930b-3f3b78c45420f9cb9dd03589ce51503b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_04.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_28.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d0716f81f387d6a3d53fbe57a54349b1-daae9ac16d648f3f65c8b3ca3a43f12d:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_28.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/ecee48fd74706a4b8ae4956c2b2f0276-f4fb1c4576fb424d6b41357256e3e852:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_05.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_29.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/2b1a177eeb390db9cb81de040ce0709c-a5975671b2a82ddd7e9c5972b15677d9:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_29.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/15636fb891307702b98a9a0e0324b385-203a5a5330ee58e5247d24b0807a6a1a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_06.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_30.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/dd1700901e2a1ccbb64a21c62da1eed0-d3b4c4f5405c9b46dc8c8da272faff3a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_30.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/8566d83af4ed8994a4083e4dcb015654-b9631d70d44bd20956e2fdc5622fb8f9:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_07.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_31.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/1cd700d3d1846c7fc152d1fc5790e125-85cc8574e0cd538fe06921d343f42807:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_31.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/1c839df0d8864ac4999f3e033201c871-04ddb6d2c7bdea4400698b34ca11beec:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_08.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/8c41edc6ee1f5a283938e6abfa746fa0-8047483355b3876fb2299fb25e6a8772:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_01.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b137951feabccaa7b7abb0c8dab6f210-3db374a17bfc2b9f3180c2b9ce36db96:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_09.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/5b14bd3daa477a885495b36d486291e6-2727912130939b73fd3bb1e6a627f1b6:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_02.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/1e928d0158df2d0bef5420573f85abdf-f694488c9e954d8365133a908c65ef68:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2070/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/6c677555d86b33af7997b2c396ab5b18-a7f660a2282c5c9738c4148b0684ed71:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_10.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/7cfc768488e4d54e0921b2cf44c0fffe-b57ed4ceeea663b9a1ae6e19666b0745:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_03.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/7f19f3ba7113019ca32f654591e9d8cf-93711cdd8047347a693834cccfc0fbcf:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_11.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/956dde4de0108d7485e952d2a9479fea-822068f015c75569b3953131db112fbf:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_04.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/210b3b4cc850dcacf071ad4e7db2f2a7-c9c105e147eb5b1534bb47d9387ae2ce:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_12.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/506165c8822827e751180dd77c458d6b-fab36eff96640837ba674782f2a879a4:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_05.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/3f7abd72d0468cd57cfd7a801ef96523-737817df47fbb3acf480ed5a1f5c0c99:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_13.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/69ee5bc6bb5d24426e8506397437ce5f-e743e5f6c23f35f9fe2fe909c0c24af4:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_06.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/fa240a0c067701cf09dd73d556c3a345-9b8dea3299f217eeddaeeb6b6181db05:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_14.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d722f385940d459e7e28b7529746adb7-a7bee4a0c25974a84aca3e1e7187b644:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_07.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/52bbe70a2a3b04021062f9346c813795-1b136b573f6ec4a46ea2f485f89061eb:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_15.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/253a469ad14fe60a6efb700e61b3302f-6b28ce585f1eef79df4d1c59d751b58f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_08.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_16.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/2ac19555ccd6acd3d4191ed9b714fe56-6fa3f655ae27eddcac158826505b4b5f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_16.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e9135eb0a376224e6a6c81c57081591a-46005e44882fadcd852f5e6060779ca6:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_09.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d41452812a3ae346972ae30b95c5f954-a6be507e15523f3054e46eb4a4c2ba6a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2071/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_17.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/c678b5a92ff75ae4f7cf9ad739661a83-b8fc99d894eec592caa494517806c24a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_17.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/247414b657de6fe2281298f390fcebd9-07bbc2c421b4b14807bc5fb993d72702:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_10.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/af60ef1a41592f31f93520374e1dfdd8-cdfb1dffba26128651d836aff26bc6b5:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_18.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/41ab71af1878322c953bceec44842c6d-ae68e4298d66982285f17edf62ab7a34:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_11.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/9204a6a6711410b7548489665db2e897-7d92f7c85dc05fcfdccf881f6116a61a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_19.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/8a79f6c5ea0d7d37e42ae52752478953-e0c3e65ea0d003901893b83a80c7e5f7:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_12.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/6696a8b1b49a149c3feac2aca2ecc145-4ff883cbca423fd301bda061ad8aaae9:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_20.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/62293a6e5ad629b9b2c527feede111ce-ab99ffa290b4f67db9f2512a03fbf12b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_13.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/057b7c85ef00129f02fefec38e4b9177-3ebe716785631c3e05a55a2551904fee:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_21.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/f4e043904295c0b4ef5b812e662002d0-9fc50dedf3d07234fb0d965c0b4eb5d5:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_14.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/941b408a5e7b58b7ca6f8a0071d0ab0d-12b8c767a7ff59470d6c1fbef11c6786:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_22.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d60992d37ccbc7a6319532cfa775e1f8-4ed52e21a45a7e7fd813222688c9f24d:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_15.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e1b3fb551e528e23fc4892848dc14cd8-4cbc66c77c852a251f90987d43c3496c:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_23.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_16.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/ff228b820563ba5a76f67c35387cce8c-ffb85c94307b7831a4ccbfde30e651e8:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_16.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/6858a8af41bb1719afe8bdea19e6a1b1-ac95ef80aee301e0e7842a25671252a9:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2072/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_24.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/4834f3ca5a2d970b8f2a921f51e22050-f7b7fd3f159730d15f402cf5a116a0db:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_24.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_17.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/455443d5061ab25b1841ec3874cdea77-777287ccdd2e6477665975ba4dc10878:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_17.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_25.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/9b8847207d65e610c5898525be4d28fe-38e9b7b4a5eea0bff21b84240420e338:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA2/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_25.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA2/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/60924ecc2b9c5559a3e5a3a402ec58f9-62af69996e889700e2ec04b2e1c99b71:getPixels
# Please wait ...
