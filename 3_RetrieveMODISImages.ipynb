# %%
#!/usr/bin/env python

## MSC_Thesis 
## Jacotte Monroe 
## 19/03/24

## Script that reads the spatial and temporal extents and retrieves the matching MODIS 250m images. 
## MODIS dataset is cloudmasked using a bitmask from MODIS 500m, then gap filled using temporal linear interpolation. 
## Each image is reprojected to EPSG 32733 (Namibia projection) and clipped to study area. 
## NDVI is calculated. 
## Script inputs: 
##       0_single_run_settings.csv
##       2_a1_step_extents.csv
## Script outputs: 
##       3_a1_modis_images (folder) > [daily_MODIS_NDVI_250m_date].tif (intermediate output) & 3_a2_modis_ndvi.tif (intermediate output)

 

###########
## Script set-up and loading necessary libraries 
###########

import ee
ee.Authenticate()

import geemap
import os
import pandas as pd
import math 

ee.Initialize()



###########
## Functions needed to run the script 
###########

# function to extract and combined relevant QA band bits/flags 
# source: https://mygeoblog.com/2017/09/08/modis-cloud-masking/
def getQABits(image, start_bit, end_bit, band_name):
    pattern = 0
    
    # for each bit/flag of the QA band --> assign new value to its bits 
    # so each flag will have a different value and the pixel will be the sum of all flags 
    for i in range(start_bit, end_bit):
        pattern += math.pow(2,i)
    # return single band image of extracted QA bits
    # source: https://developers.google.com/earth-engine/apidocs/ee-image-bitwiseand
    return image.select([0], [band_name]) \
                .bitwiseAnd(pattern) \
                .rightShift(start_bit)



# function to mask out cloudy pixels 
# source: https://gis.stackexchange.com/questions/308456/get-a-mask-for-modis-250m-mod09gq-using-modis-500m-mod09ga-in-google-earth
# source: https://mygeoblog.com/2017/09/08/modis-cloud-masking/
def maskClouds(image):
    # selects the MODIS 500m QA band 
    QA = image.select('state_1km')

    # creates a cloud&shadow flag from specified bits --> in this case: 'Cloud state' and 'Cloud shadow'
    pixelQuality = getQABits(QA, 0, 2, 'cloud_and_shadow_quality_flag')

    # returns image masking out cloudy pixels 
    return image.updateMask(pixelQuality.eq(0))



# function to add timestamp band to image
# source: https://spatialthoughts.com/2021/11/08/temporal-interpolation-gee/
def addTimestamp(image): 
    # create new image where pixel value = time of original image
    timeImage = image.metadata('system:time_start').rename('timestamp')

    # mask new time image with original image to remove cloudmasked pixels
    timeImageMasked = timeImage.updateMask(image.mask().select(0))

    # return original image with time image as new band 
    return image.addBands(timeImageMasked)



# function that takes image and replaces masked pixels with linearly interpolated values from bef/aft images
def interpolateImage(image):
    image = ee.Image(image)

    # get list of before/after images from image property
    beforeImages = ee.List(image.get('before'))
    afterImages = ee.List(image.get('after'))

    # create image collection of before/after images
    # mosaic() combines images into one image accordint to their position in collection 
    #  image first has all pixels from last image in collection 
    #  gaps filled with second to last image from collection ...
    beforeMosaic = ee.ImageCollection.fromImages(beforeImages).mosaic()
    afterMosaic = ee.ImageCollection.fromImages(afterImages).mosaic()

    # rename time band of images 
    time_bef = beforeMosaic.select('timestamp').rename('time_bef')
    time_aft = afterMosaic.select('timestamp').rename('time_aft')
    time0 = image.metadata('system:time_start').rename('time0')

    # combine all three single band time images into one image with three time bands 
    timeImage = ee.Image.cat([time_bef, time_aft, time0])

    # compute image of interpolated surface reflectance values 
    timeRatio = timeImage.expression('(time0 - time_bef) / (time_aft - time_bef)', \
                    {'time0': timeImage.select('time0'), 
                     'time_bef': timeImage.select('time_bef'), 
                     'time_aft': timeImage.select('time_aft')})

    interpolated = beforeMosaic.add((afterMosaic.subtract(beforeMosaic).multiply(timeRatio)))

    # replace masked pixels in current image with pixels from interpolated mosaic
    result = image.unmask(interpolated)

    # return gap-filled image
    return result.copyProperties(image, ['system:time_start'])



# function to reproject (elephant fixes reprojected from 4326 to 32733 same needs to be done to images) 
def reprojectModis(image):
    return image.reproject('EPSG:32733', None, 250)



# function to clip image to study area
# have to include nested function because can't use map() with more than one argument 
# source: https://gis.stackexchange.com/questions/473500/mapping-function-with-multiple-arguments-in-google-earth-engine
def clipToAOI(bbox): 
    def withBbox(image):
        return image.clip(bbox).copyProperties(image, ['system:id'])
    return withBbox



# function to calculate NDVI 
def addNDVI(image): 
    ndvi = image.normalizedDifference(['nir', 'red']).rename('NDVI')
    return image.addBands(ndvi)



def retrieveMODISImages(): 
    # source: https://stackoverflow.com/questions/44116194/import-a-function-from-another-ipynb-file
    #from ipynb.fs.defs.pythonFunctions import getQABits, maskClouds, addTimestamp, interpolateImage, reprojectMODIS, clipToAOI, addNDVI
    
    ###########
    ## Read run settings 
    ###########
    run_settings_table = pd.read_csv('data/single_run_settings.csv', index_col = 0, header = None)

    ID = run_settings_table.iloc[0,0]
    week = str(run_settings_table.iloc[0,1])
    random_data_method = run_settings_table.iloc[0,2]
    input_suffix = run_settings_table.iloc[0,5]
    output_suffix = run_settings_table.iloc[0,6]

    # replace NA from suffix columns of run settings to empty strings
    #if input_suffix.isna(): 
     #   input_suffix = ''
    #if output_suffix.isna(): 
     #   output_suffix = ''
        

    ###########
    ## Load step extents LUT
    ###########
    extents_lut = pd.read_csv('data/' + ID + '/' + week + '/' + '2_a1_step_extents_LUT_' + random_data_method + input_suffix + '.csv')



    ###########
    ## Create region (largest extent) geometry and define first and last dates
    ###########
    large_extent = extents_lut.iloc[-1]

    large_extent_coords = [[[large_extent.loc['xmin'], large_extent.loc['ymin']],
                            [large_extent.loc['xmin'], large_extent.loc['ymax']],
                            [large_extent.loc['xmax'], large_extent.loc['ymax']],
                            [large_extent.loc['xmax'], large_extent.loc['ymin']]]]
    
    large_region = ee.Geometry.Polygon(large_extent_coords, proj = 'EPSG:32733', evenOdd = False)
    
    first_date = ee.Date(large_extent.loc['start_date_prev_week'], 'Africa/Maputo')
    week_start_date = ee.Date(large_extent.loc['start_date'], 'Africa/Maputo')
    last_date = ee.Date(large_extent.loc['end_date'], 'Africa/Maputo')


    
    ###########
    ## Load feature of Etosha National Park (Namibia) and transform into geometry
    ###########
    # load Etosha National Park study area
    enp = ee.FeatureCollection('WCMC/WDPA/current/polygons') \
            .filter(ee.Filter.eq('ORIG_NAME', 'Etosha'))
    
    # turn ENP study area into a geometry
    enp_geom = enp.geometry()


    
    ###########
    ## Set interpolation parameters 
    ###########
    # set time-window for interpolation (how far will interpolate)
    # source: https://spatialthoughts.com/2021/11/08/temporal-interpolation-gee/
    days = ee.Number(30) 
    
    # convert to milliseconds (for gap filling step)
    millis = days.multiply(1000*60*60*24)


    
    ###########
    ## Define path of output directory 
    ###########
    # define output folder paths for current MODIS images and images from week prior
    out_dir = 'data/' + ID + '/' + week + '/' + '3_a1_modis_images_' + random_data_method + output_suffix + '/'
    
    
    
    ###########
    ## Retrieve MODIS datasets and combine into one dataset
    ###########
    # load MODIS 250m dataset 
    # take larger time range to include images for gap filling of cloudmasked pixels 
    # source: https://developers.google.com/earth-engine/apidocs/ee-date-advance#colab-python
    modis_250 = ee.ImageCollection('MODIS/061/MOD09GQ') \
            .filterDate(first_date.advance(days.multiply(-1), 'day'), last_date.advance(days, 'day')) \
            .filterBounds(enp_geom)
    
    # import MODIS 500m dataset (contains information for cloudmasking)
    modis_500 = ee.ImageCollection('MODIS/006/MOD09GA') \
            .filterDate(first_date.advance(days.multiply(-1), 'day'), last_date.advance(days, 'day'))  \
            .filterBounds(enp_geom)
    
    # combine datasets
    # pixel with certain MODIS 500m value can be selected for MODIS 250m 
    # source: https://gis.stackexchange.com/questions/308456/get-a-mask-for-modis-250m-mod09gq-using-modis-500m-mod09ga-in-google-earth
    modis_combined = modis_500.combine(modis_250)
    
    # new name of MODIS 250m bands (to avoid having two of similar name)
    modisBands = ['sur_refl_b01_1', 'sur_refl_b02_1']
    renamedBands = ['red', 'nir']



    ###########
    ## Create cloud free MODIS 250m dataset
    ###########
    # source: https://mygeoblog.com/2017/09/08/modis-cloud-masking/ 
    # source: https://gis.stackexchange.com/questions/308456/get-a-mask-for-modis-250m-mod09gq-using-modis-500m-mod09ga-in-google-earth
    
    modis_cloudFree = modis_combined.map(maskClouds).select(modisBands, renamedBands)

    
    ###########
    ## Image gap filling - Linear interpolation of missing pixels 
    ###########
    # add timestamp band to each image 
    modis_cloudFree_withTime = modis_cloudFree.map(addTimestamp)
    
    # following tutorial: https://spatialthoughts.com/2021/11/08/temporal-interpolation-gee/
    # define filter to only retrieve images within the specified time-window
    maxDiffFilter = ee.Filter.maxDifference(difference = millis, 
                                            leftField = 'system:time_start', 
                                            rightField = 'system:time_start')
    
    # define filters that compare given image timestamp against other image timestamps
    # NOTE: leftField compared against rightField --> so in first filter = leftField smaller than rightField
    greaterEqFilter = ee.Filter.greaterThanOrEquals(leftField = 'system:time_start', 
                                                    rightField = 'system:time_start')
    
    lessEqFilter = ee.Filter.lessThanOrEquals(leftField = 'system:time_start', 
                                              rightField = 'system:time_start')
    
    # combined filters --> find all images before/after image that are within time-window
    filter_before = ee.Filter.And(maxDiffFilter, greaterEqFilter)
    filter_after = ee.Filter.And(maxDiffFilter, lessEqFilter)
    
    # set join parameters
    # pairs each image to group of matching elements from the second collection 
    # saves the matching elements as new property with matchesKey name, ordered by date
    # order set to have the closest image as last element in list
    # source: https://spatialthoughts.com/2021/11/08/temporal-interpolation-gee/
    # source: https://developers.google.com/earth-engine/apidocs/ee-join-saveall
    join_before = ee.Join.saveAll(
        matchesKey = 'before', 
        ordering = 'system:time_start', 
        ascending = True)
    
    join_after = ee.Join.saveAll(
        matchesKey = 'after', 
        ordering = 'system:time_start', 
        ascending = False)
    
    # join the cloudfree MODIS 250m collection with itself to get all previous/post images within time-window
    # results in image collection where each image has a property that lists all images preceeding/following image within time-window
    # source: https://spatialthoughts.com/2021/11/08/temporal-interpolation-gee/
    modis_joined_temp = join_before.apply(
        primary = modis_cloudFree_withTime, 
        secondary = modis_cloudFree_withTime, 
        condition = filter_before)
    
    modis_joined = join_after.apply(
        primary = modis_joined_temp, 
        secondary = modis_joined_temp, 
        condition = filter_after)
    
    # interpolate all images from MODIS 250m image collection
    modis_interpolated = ee.ImageCollection(modis_joined.map(interpolateImage))
    
    
    
    ###########
    ## Look over each step extent entry in the LUT to export corresponding image 
    ###########
    # 1. get dates
    # 2. get coordinates 
    # 3. turn into geometry
    # 4. get MODIS image
    # 5. reproject 
    # 6. clip
    # 7. calculate NDVI
    # 8. export image
    
    for i in range(len(extents_lut)-1):
        # select entry
        extent = extents_lut.iloc[i]
        
        # retrieve extent dates 
        start_date = extent.loc['start_date']
        end_date = extent.loc['end_date']
        
        start_date_prev_week = extent.loc['start_date_prev_week']
        end_date_prev_week = extent.loc['end_date_prev_week']
        
        # retrieve extent coordinates 
        # source: https://sparkbyexamples.com/pandas/pandas-get-cell-value-from-dataframe/?utm_content=cmp-true
        # source: https://stackoverflow.com/questions/75203044/how-to-create-polygon-from-bbox-data-in-pythonv
        coords = [[[extent.loc['xmin'], extent.loc['ymin']],
                  [extent.loc['xmin'], extent.loc['ymax']],
                  [extent.loc['xmax'], extent.loc['ymax']],
                  [extent.loc['xmax'], extent.loc['ymin']]]]
    
        # create geometry from coordinates
        bbox = ee.Geometry.Polygon(coords, proj = 'EPSG:32733', evenOdd = False)
        
        # retrieve MODIS 250m image for geometry 
        modis = modis_interpolated \
            .filterDate(start_date, end_date) \
            .filterBounds(enp_geom) \
            .select(['nir', 'red']) 
        
        modis_prev_week = modis_interpolated \
            .filterDate(start_date_prev_week, end_date_prev_week) \
            .filterBounds(enp_geom) \
            .select(['nir', 'red']) 
        
        # reproject image
        modis_reproj = modis.map(reprojectModis)
        
        modis_prev_week_reproj = modis_prev_week.map(reprojectModis)
        
        # clip image
        modis_clipped = modis_reproj.map(clipToAOI(bbox))
        
        modis_prev_week_clipped = modis_prev_week_reproj.map(clipToAOI(bbox))
    
        # calculate NDVI 
        modis_ndvi = modis_clipped.map(addNDVI).select(['NDVI'])
    
        modis_ndvi_prev_week = modis_prev_week_clipped.map(addNDVI).select(['NDVI'])
        
        # export MODIS image to local repository 
        # source: https://github.com/gee-community/geemap/blob/master/examples/notebooks/11_export_image.ipynb
        geemap.ee_export_image_collection(modis_ndvi, out_dir = out_dir, region = large_region)
        
        geemap.ee_export_image_collection(modis_ndvi_prev_week, out_dir = out_dir, region = large_region)
    
    
    
    ###########
    ## Create and export mean NDVI image for large extent 
    ###########
    # This image will be used as basemap for visualization (no analysis done with it)
    # filter dataset to dates
    modis_week = modis_interpolated \
        .filterDate(week_start_date, last_date) \
        .filterBounds(enp_geom).select(['nir', 'red']) 
    
    # calculate NDVI 
    modis_week_ndvi = modis_week.map(addNDVI).select(['NDVI'])
    
    # create mean NDVI raster
    # source: https://developers.google.com/earth-engine/guides/ic_reducing
    modis_ndvi_mean = modis_week_ndvi.mean()
    
    # reproject image
    modis_ndvi_mean = modis_ndvi_mean.reproject('EPSG:32733', None, 250)
    
    # clip image
    modis_ndvi_mean = modis_ndvi_mean.clip(large_region)
    
    # export image
    geemap.ee_export_image(modis_ndvi_mean, filename = os.path.join(out_dir, "mean_ndvi.tif"), region = large_region, scale = 250)

    return print('(DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.')
    #print('Now extracting covariates...')


# read the table with all run settings
all_runs = pd.read_csv('data/run_settings_new_path_with_CV_rerun.csv', index_col = 0)

# iterate over each entry in the table 
for i in range(len(all_runs)):
    # save the run settings to be read in the function
    row = all_runs.iloc[[i]]
    row.to_csv('data/single_run_settings.csv', header = False)

    # run function for MODIS image retrieval
    retrieveMODISImages()
# Out:
# Total number of images: 1
#
# Exporting 1/1: data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/5675137b3f011c9345d3299d51c2a800-7688347dc494a49ca25b2f4c9108cf50:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_15.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/9eece8f01684e61e29a7a39a8010d3a0-de2b50553010ef2e58acd1216a114e4b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_08.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_16.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/8a0ffd000bad122d51e8fafb221c87e3-fdd2e932243e478b7a13fefe48b589fa:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_16.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/636c78e8ea17856c4222d89977458b31-5965ff1a41a2f379b928cfdc59d50042:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_09.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_17.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/037fb9891e1b78acc0ecfc88eb6074d1-44105f4511b171dee168987c252b508a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_17.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/f4e336b00e0c902676fed29487682fea-a54c661883160fd33664bbcc14d36e6a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_10.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/58cb399bb9b37027d1f9efce098dde90-c3171c9506662820beee79650a2cf013:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_18.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/40ffd2c84719bfa857d01c9ec1f1b1f4-fbbfa9008d139fc99a0c7aaaaf0b220c:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_11.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/62fb6399cacaa2e4444da649c610f732-39dc24930be9b6a630fa5cb6589d77b9:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_19.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/77c8fc894bd104374f74a6b9784673f9-22a3b038220942cc349e439c40930792:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_12.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b789f38d252ea41434b4ffc882f4b403-287dadd6b54e76f80dbf1ee972040378:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_20.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/8113c8d149478ab5cf78c314a1009e63-3528a26e644b97b72d2ea771690d3cfe:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_13.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/8f9f64bf148920e47a8b70f7e7534fc0-e77e0131109f685e437d6e4427b31a37:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_21.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e4d7c2dcac1eaf496c41c1266ddbb5ac-d38a103eef3f82068b7d5f3dc6325d9f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_10_14.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/9045f0e7ed100bda52e407c5189fc128-db8397abc56f1c6ae7ae8b4a01d466b5:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA4/2076/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_27.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/4867e01d2bf562cac68b74f9a339bdb2-55859f0e82c6f5ad7d893c1d6e91d4b2:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_27.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/144c4d734ee8544bfd840c17b5a63d8e-d57405d4c7be36428b822e241d184835:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_20.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_28.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/f714d1982be4f38846d2d8a6c0386cc1-3d9dd060083a318a18f4d9cd4d8e71d6:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_28.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/74f94514798480f5701b7cb39426b21a-294982ae035faad382106619a858af98:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_21.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_29.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/c5154aaf9dd7dfbfe6b235ab82d25e36-fe0b6472a846fc8a0c0061b0c96c69fd:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_29.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/494fb5a6539ad63be47bcc9fe50efccf-be24c067b89b76c5110a0e63e0e52565:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_22.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_30.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/f9ff62a681a52a13a491495b1b399f10-4c85dd11a8f989e3fcdcb4be2e3cb116:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_30.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/6ad65e17d5f6817eaee8fcb2bcce5aa7-b942ec5ada4fa811a0981dd6f2c221d6:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_23.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_31.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/90a791b46530fb70337fd84754016bfe-ac8f748f42f139e5917bfeee85f367d9:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_31.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_24.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/9632201b6fada5836522851322413358-6bb5151ac87100527d0b6e9e50552d75:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_24.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/fd132513e3ec56eab8e597964630b168-e63e1feefbd00b358f66acaccd030530:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_01.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_25.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/19f86a2e7373eb0b9cb783f875c6077c-b6343c115144af0f1e9280d6bbe53495:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_25.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/c1bb4e063b416c63d6c50232829e07c8-c9d5dead758ed397343a6e268ebad117:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_02.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_26.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/a5086c6edb6e7a98e4b4e218b0984ac9-15c8b4427098b4e13f079512d9ef58aa:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_08_26.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d71b90c7299bc0433cbe3cccb96377f3-33156bb44fe8c7eb9cebbec3473b5c87:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA7/2069/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_26.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/1bfc006ff297f0f0ea67b172b4f68463-fe228093bf59421dd8199012f96f407a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_26.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/c8fef12b813bb528360dbd36c56ccec0-2b6c356adf43baad004cef56b8ad4e2e:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_19.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_27.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d3c50448ed741aacb0fa06e60ccfe541-a91066ea986e6ce078450dd5eeb4cfab:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_27.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/473c5e4ad626836f52aaa6133ed58e8e-b250c5530ad8ab74ab5fef31bf241dfb:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_20.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_28.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/7701f5288c6559ad86cf6dd299d33ced-6d34011f0cd4b1984ad81c3ef0f62111:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_28.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/ae470bf136d4747c6339f286efa3ac3d-616187c6dd9e48d5be513f18a0a5f20f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_21.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_29.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/6116e7bf0ab8a347988f6ebcdf426c40-eca2529bde72ad81cc32e542e85759f1:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_29.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/6956d58fe43c166b4380f4d3a9fed594-069c355e74431ceb080b61618c756c0c:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_22.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_30.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/2d01292dddf378fab3ffe175c27889e2-7f9998aae428deb15d51032aba918a4b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_30.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/5f3e96044759abeeaed04430295bd6d7-58e931cfacbfad9306dd81ad864804a0:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_23.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b89f6ad3e888783b2d386da8883c691e-da9ffcd59b2a89df5f04eb692cba70b9:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_01.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_24.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/ada8bf2181f159cd0d3036066f8a87a5-5c33290edef2aeb44b8d9b7ced068f18:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_24.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/5ecd68124a4ddbdcb7227757ed014cf7-295666edd884dd484e2ead677e4984c7:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_02.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_25.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/699477001b8f31ee75f47ec04cd84ed0-85334f9c8bfe1fdc9e342b9dd3893acc:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_11_25.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/a7af2272261031fb5cd15a4ca8cf740b-e3c0ea3a2b4bf57a85c84f0b0d8b81b5:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA6/2082/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_24.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/71ef95c16de7353985782559ff5dce3d-3b8b258be8aa6077fb964c6b709f7c3d:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_24.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_17.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/95c11a9dff310d5ec2159dadc71e4049-955e5e135226110818cd86207b5587c2:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_17.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_25.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/eb8aee642268fa006ad14da323696034-7430058ef8c59d90ff6d813171176940:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_25.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/cabc5ed2d707ff0dc004ca3ed50c7baf-6b3b34182a1801fc3b32487e74c1e9b9:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_18.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_26.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/a063f13b0611f2d415a0b9046a61a963-f7d53aa0ff48fda1c0bb06b6495b197b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_26.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/7be76191ff65239a3f676f81beeb8b75-8514fa7bbe08be36d7bdca8d245cec52:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_19.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_27.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/a4504b76ea70ba6e7dd66428f4bf4434-734146504a82c8e4698ed815116ba538:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_27.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/f047fd56ad22f5b51d265217f26b70dd-e0ff9b29908d04bb16f1c0c9e4c467ed:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_20.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_28.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/c9ff9042f4812c2efea407969a595d52-abf18f7a4872ba59c79a2b75cda9a30d:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_28.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/bca4403d4b1acc179a14ec46089bca57-ce0fd3ab91637e10c642321276a39e96:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_21.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_29.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/6213fb3d864a5231c1ef8fd05cd42d2b-d5d431b01ea1b71c6014cded7cd79898:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_29.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/0cfe52636580ab7f2af95286badbe2af-0eb2962d6473e74073866bbd50d4f164:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_22.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_30.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b9082d9c6c03ae19cb75e97d06cd94e6-a71e37c916f4e9520a109bcae322ab5b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_30.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/89c299c8b4b2bf62ace508e54c0815a6-e52292fab6a0e525146e81add30b6b0b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_09_23.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/34ce75a11a61a9f9b52cf60a62368a0b-136b6ed679610906406c51706c03e931:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2073/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/57ea94e57b3815391b310ab9bcf63dc0-7f09f483c1bde46fdb36508f67f6f47c:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_07.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_31.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/a6139b1a7a4f0ff798d1f178d302ae2c-dc85f84dfcb43520788f984c7e5f48b6:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_31.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/0f691cc6debfc9e5649a46847745723d-adeb88d1bb98f747ca5f5ea4aa21f142:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_08.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/15420a33a57652af1da811e0fc36be54-c7747da249fd638bcdbc07690e6e8875:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_01.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/66ae111d264ce24e19a6eb51930611a8-0403d93328ddf2d2bd7fb86ab2082ce8:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_09.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/4e63ea27e252c94e0ffe3b6cb1d8e6ac-7142d52885aed992fb5b75749af8024b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_02.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e91eccf974eb30dfebaecc5015bd337e-54c7c3f7617161bbb1fbfb05e62dd745:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_10.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/edc8855c420fa671e5a21617f7e4354a-87680d31f788f6e38d9229027f8e3682:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_03.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e9d0e89cd1b89244e3cba374aa2d09f8-84c95f3019fa5e22168bee54c17bde5e:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_11.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/af935c823457aa9aed69237debc9657d-d57f0c0205ab4c0bff0eef26117422f4:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_04.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/0cc9fb6e881c3c344bede7de8d620228-f6d243321678e250370d2f82a0a8aca0:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_12.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/ae03424674a55a9b8006fb9ba6304f5c-e310de820b602f33af81b5a5b9df8ba2:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_05.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/de292f3c1ae0f1ca1432f7f1c4152d1d-1913b84113f0dc007e680d245517e667:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_13.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/980e3c88abb00f21b75877eb0c43aede-66c0ecc84e16ccf20e9aa71cbbe840f3:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_01_06.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/86f0d72aa6aa6f4bd5f9d66d3f9cc30b-241b4d95a19be76f89922991709ec871:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA14/2088/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/5589849e1a6bbed774c2a112cdcdc7f7-7055c84d0b6181dfb9d6159632ba962d:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_10.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/afb4e70422ad972e7397520af0d5b0e0-2cc28d85187a015ff501d8b70b9bb3cf:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_03.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/2af5cc8fdb8ddbfd596ad5d008e519e0-53ab57488b94fc7035241b24a9a2308a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_11.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/11a9309ad3d2607c42a007852b441614-e7c0bffcb885709d79410744176b708b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_04.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/cf895a4a298251eba79c26baeb689563-7a0fa843a12a1219cd2bde78c5634e94:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_12.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/7bbcee359b9079ef92dfee015fff93c3-5c468399213e9bf79ab1310e6375dcc2:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_05.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/38dbc26afccd48c5ff969517791656c2-8c77de00492a2ae0b82c296d31d4b696:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_13.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/70eeee5aff61b8768fa95614a38ea9b4-b32899321e08f44eb4e6e550cde4bf82:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_06.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/ccc9fcc275ecd221f80d90f90fb4a381-c9a64d077d4c336c52321406e1fcc757:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_14.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/2d78b9e85efc30b3c1e383d0b73fd02b-0d2129ff540b4fe6d2528bd3a98dce83:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_07.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/3468d4779fb1c93fdc29326620c1e914-15fd629db8e147ce30fb119bc0b7e0ed:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_15.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/9c1b64c16d5f37c509971d33f4fc0426-cb9ae1f1b736f0904f2dc3753d843cce:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_08.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_16.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/4cd87f661ce9cbea4563022631bc6b36-381e7f07412ab0b70f924d9cdb09d162:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_16.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d60b80cdd83e0378ad33be5cdd24f7fa-db5b5ba783e67d30617c68a96d266ff7:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2009_12_09.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b352537affbe6678b7d2bceff61a7a6f-09486c00b6771923a4c19b60f6e80a3b:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA12/2084/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/300597005e677db17e4be1761e8fe13d-1dbe415cefeb755879569a186208ab2f:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_18.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/0668dc4098422f0f8f5f15c4ab48b8a4-345e30a5e98b9f362574b8b36fe1cf7d:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_11.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/c56f1631a81241bf27d1aa328baeb834-0759e18cbc5103eb8e19a1ed6d6da477:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_19.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/0fb7edbcb3307aededd74f1aeb2c3ae0-54bcc62f97807952f4a7ccb3c210fe55:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_12.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/0ff20b5af57c50ccb62414713ab567d8-0b865e4b7edf461cb0061545f9698cee:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_20.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/5c4b5abab5f13f82afe1301d4ff82e82-8dedd0c69e1a1365c673a7838e522b42:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_13.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/3d0f6c520d9c82f8c5069e8fe21884e6-4575ad7d2583ce1e18e5d0073ec4fb8d:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_21.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/cf523f5dc471932c866d22e9c5c0a039-dd4fd52286aa1159f044871fb3da9ae8:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_14.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/347a2ac8fdc616e3c472625eab62b2df-1a1b0aa6bca7386f3f8f33b4487c1bab:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_22.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/5d5cdee6d81393f21e7701852330d754-6e3022875c4f6ea18e0e0a3057cd1693:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA11/2098/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2010_03_15.tif
#
#
# Total number of images: 1
#
# ...
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2176/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2011_09_11.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2176/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2011_09_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/8f5d4a41b3e2e4d2f2fd2d308daf3df8-389daf5e3bbbe8f749fb488b47b276b7:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2176/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2011_09_19.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2176/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2011_09_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/9e8b6e134f64f6ab123cce697c1c0855-a77a3c9033d66881d6a0c7f1b9b0cfbb:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2176/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2011_09_12.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2176/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2011_09_20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/84907b5bda0585d458eb925f4d847cca-09e1bff7f6bcfd73a69778ec925ad86d:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2176/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2011_09_20.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2176/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2011_09_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b8f4e0c4dae069d7ed62c6c72b45a9f3-a8fbb58e57c66de2985c90561bd1e188:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2176/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2011_09_13.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2176/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2011_09_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/38c5046f5330d0abf87afb5cc38aeb94-7d601abcf5ac8d5754b447729c11ab10:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2176/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2011_09_21.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2176/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2011_09_14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/751df8eddda2fa3531420c03c4180d32-bc2ef5d9bdbd8915b32645b1a56a9b73:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2176/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2011_09_14.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/69a68f369aca18f55c7bcff37621bb3f-b3d88d5c318712bbdeaea64eefcb5aed:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2176/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/7950e76edc2c8e5dd2b0ab99f44ccb34-2b76f3d211fbe09b472f9a57041347bd:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_21.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/93702f5810714c9f5c0c10b36de2bf93-029dee5ed3327431a0579f7e500e2c56:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_14.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/1c03c434cb9dd1ed89c55284eea7f381-a0a0c604e7a5d56960149b6d069b643a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_22.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/cd709cc7d5f700fbb7b806c977a5fdef-767698b91bd956594e1605ea333b70ba:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_15.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d1c550b9fc88d04631f27c46a5db76fc-8a35e1d3997d6f34c3bd34ce41bd6b32:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_23.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_16.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/e5358bd64d9babe78aa9681757ac0859-58242732bf595b5ba75a49bc98aaf3e9:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_16.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_24.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/da042af5df36281eb03c55ad543aeacd-149f7be50321a059dc8e24dbfd51445d:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_24.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_17.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/1e340843a11913dc34e026b6b687c72a-35aba97efc067f113dd18c0b6bc4a75a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_17.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_25.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/dc4ae8226ca66ae26a2aa3557654395e-c71748c1504b3edff3107ffc412ab441:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_25.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/b224660a42202e608aec410e4e9a7ddf-120774e092c69a7492d84600828f6ac3:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_18.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_26.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/0db6112a9db1a63dc2ece96d52ca2d75-c3ef264e9ca03a81ffe7e0b2fa139ba3:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_26.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/c8529cd6bf750f3451d45551d4348d9d-60d7429c35cf142906fd9c65e0edeb1e:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_19.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_27.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/351bfe590d0f2e3644c24e3927f552da-5bd4ca63232c07b50496bd69c8d1a453:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_27.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/54d9d4433411e3f80c5515a07138b2cf-18b18180f4c0d751f6de4e7154cd9e2a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2012_06_20.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/371d3f0544298a393275a52f4296b1ef-1e9a0d1f12f266a06042c8da96745c56:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2216/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/33931d8208453d3d90e21bbb48631642-12dca51f78a47300454efb6998a9f419:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_20.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/a3ba9622861df3ae734902d6c9536d24-1a3c899b508bc6620a5429cf46a2cc04:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_13.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/fb433d9d9f796328ecb5e988a9d003b0-d04b0510689f072114c32431f74b0719:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_22.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/fc2c8e6844b168035b969bff66b2b26e-c931d2c0fa3ed1a25e94e5bd240e8387:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_15.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/f175b5e420aa307c6d08b3feb7d19095-7b8d08c4319101cc7e965d130ba23225:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_23.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_16.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/647e5d334266eeb556e064a386bfed8a-f90cda131bd52f544644c95628f4494e:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_16.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_25.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/899e26558d35f49323fda4eea67bfd16-679a1402560d1f8cf656db1a57ea3961:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_25.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/4b9b1a9473a5afe5c5f84425a6f16065-858546c0b58d987411db449051fb3339:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_18.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_26.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/000b4ce2a1f4d46a95c74089cbc85ba5-bdac7977b5a6d1220d39efbd8b0bb670:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_26.tif
#
#
# Total number of images: 1
#
# Exporting 1/1: data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/48246f377607d16f6cff1c9751af17b3-4401824bc6851b7c0dbebce6ca355927:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/2013_06_19.tif
#
#
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/d99b0a08b478d39db1b8a4884261c71d-c924ee3f31ce5278e9b4f61dcf36229a:getPixels
# Please wait ...
# Data downloaded to /home/osboxes/Documents/MSc_Thesis/data/LA26/2268/3_a1_modis_images_random_path_custom_distr_newPathWithCV/mean_ndvi.tif
# (DONE) Retrieving cloudmasked and filled MODIS 250m NDVI images corresponding to the movement steps.
